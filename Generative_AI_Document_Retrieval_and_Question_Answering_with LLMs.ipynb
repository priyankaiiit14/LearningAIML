# %% [markdown]
# <a href="https://colab.research.google.com/github/priyankaiiit14/LearningAIML/blob/main/Generative_AI_Document_Retrieval_and_Question_Answering_with%C2%A0LLMs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Generative AI - Document Retrieval and Question Answering with LLMs

# %% [markdown]
# ## Authenticate

# %%
from google.colab import auth as google_auth
google_auth.authenticate_user()

# %%
# !gcloud config set project sascha-playground-doit
# Out:
# Updated property [core/project].

# %% [markdown]
# ## Dependencies

# %%
# !pip install google-cloud-aiplatform==1.25.0
# !pip install langchain==0.0.187
# !pip install xmltodict==0.13.0
# !pip install unstructured==0.7.0 # used by langchain
# !pip install pdf2image==1.16.3 #used by langchain
# !pip install requests==2.31.0
# !pip install beautifulsoup4==4.12.2

# %%
PROJECT_ID = 'sascha-playground-doit'
REGION = 'us-central1'
BUCKET = 'gs://doit-llm/embeddings'
DIMENSIONS=768
DISPLAY_NAME='palm-2-langchain-document-answering'
ENDPOINT='us-central1-aiplatform.googleapis.com'
TEXT_GENERATION_MODEL='text-bison@001'

sitemap='https://cloud.google.com/vertex-ai/sitemap.xml'

# %%
import os
from google.cloud import aiplatform

aiplatform.init(project=PROJECT_ID, location=REGION)

# %% [markdown]
# # Documents
# ## Parse the sitemap

# %%
import requests
from bs4 import BeautifulSoup

def parse_sitemap(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, "xml")
    urls = [element.text for element in soup.find_all("loc")]
    return urls

sites = parse_sitemap(sitemap)

# %%
sites_filtered = [url for url in sites if '/reference/' not in url and '?hl' not in url]
sites_filtered
# Out:
# ['https://cloud.google.com/vertex-ai/docs/general/iam-permissions',
#  'https://cloud.google.com/vertex-ai/sla',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-get-model-evaluation-tabular-regression-sample',
#  'https://cloud.google.com/vertex-ai/docs/tutorials/tabular-bq-prediction',
#  'https://cloud.google.com/vertex-ai/docs/experiments/tensorboard-profiler',
#  'https://cloud.google.com/vertex-ai/docs/tutorials/image-recognition-automl/training',
#  'https://cloud.google.com/vertex-ai/docs/start/automl-users',
#  'https://cloud.google.com/vertex-ai/docs/training/neural-architecture-search/nas-tutorials',
#  'https://cloud.google.com/vertex-ai/docs/tutorials/image-recognition-custom',
#  'https://cloud.google.com/vertex-ai/docs/text-data/sentiment-analysis/interpret-results',
#  'https://cloud.google.com/vertex-ai/docs/core-release-notes',
#  'https://cloud.google.com/vertex-ai/docs/generative-ai/code/test-code-generation-prompts',
#  'https://cloud.google.com/vertex-ai/docs/generative-ai/release-notes',
#  'https://cloud.google.com/vertex-ai/docs/training/automl-edge-api',
#  'https://cloud.google.com/vertex-ai/docs/tutorials/image-recognition-automl',
#  'https://cloud.google.com/vertex-ai/docs/predictions/online-prediction-logging',
#  'https://cloud.google.com/vertex-ai/docs/python-sdk/training-classes',
#  'https://cloud.google.com/vertex-ai/docs/featurestore/managing-entity-types',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-predict-tabular-classification-sample',
#  'https://cloud.google.com/vertex-ai/docs/pipelines/dataflow-component',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-create-batch-prediction-job-video-object-tracking-sample',
#  'https://cloud.google.com/vertex-ai/docs/explainable-ai/overview',
#  'https://cloud.google.com/vertex-ai/docs/training/custom-training-methods',
#  'https://cloud.google.com/vertex-ai/docs/workbench/managed/cmek',
#  'https://cloud.google.com/vertex-ai/docs/generative-ai/models/tune-models',
#  'https://cloud.google.com/vertex-ai/docs/video-data/object-tracking/prepare-data',
#  'https://cloud.google.com/vertex-ai/docs/experiments/create-manage-exp-run',
#  'https://cloud.google.com/vertex-ai/docs/workbench/managed/serverless-spark',
#  'https://cloud.google.com/vertex-ai/docs/experiments/intro-vertex-ai-experiments',
#  'https://cloud.google.com/vertex-ai/docs/model-monitoring/monitor-explainable-ai',
#  'https://cloud.google.com/vertex-ai/docs/video-data/action-recognition/get-predictions',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-explain-tabular-sample',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-create-batch-prediction-job-sample',
#  'https://cloud.google.com/vertex-ai/docs/predictions/migrate-cpr',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-get-model-evaluation-tabular-classification-sample',
#  'https://cloud.google.com/vertex-ai/docs/workbench/managed/save-to-github',
#  'https://cloud.google.com/vertex-ai/docs/video-data/classification/prepare-data',
#  'https://cloud.google.com/vertex-ai/docs/datasets/create-annotation-set',
#  'https://cloud.google.com/vertex-ai/docs/explainable-ai/limitations',
#  'https://cloud.google.com/vertex-ai/docs/workbench/user-managed/images',
#  'https://cloud.google.com/vertex-ai/docs/explainable-ai/getting-explanations',
#  'https://cloud.google.com/vertex-ai/docs/experiments/user-journey/uj-compare-models',
#  'https://cloud.google.com/vertex-ai/docs/tabular-data/tabular-workflows/service-accounts',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-create-batch-prediction-job-tabular-forecasting-sample',
#  'https://cloud.google.com/vertex-ai/docs/experiments/log-data',
#  'https://cloud.google.com/vertex-ai/docs/training/hyperparameter-tuning-overview',
#  'https://cloud.google.com/vertex-ai/docs/training/create-custom-job',
#  'https://cloud.google.com/vertex-ai/docs/tutorials/tabular-automl/dataset-train',
#  'https://cloud.google.com/vertex-ai/docs/model-registry/model-registry-bqml',
#  'https://cloud.google.com/vertex-ai/docs/featurestore/setup',
#  'https://cloud.google.com/vertex-ai/docs/explainable-ai/tensorflow',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-predict-text-sentiment-analysis-sample',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-create-training-pipeline-video-classification-sample',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-create-training-pipeline-image-classification-sample',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-get-batch-prediction-job-sample',
#  'https://cloud.google.com/vertex-ai/docs/tabular-data/forecasting/evaluate-model',
#  'https://cloud.google.com/vertex-ai/docs/text-data/classification/get-predictions',
#  'https://cloud.google.com/vertex-ai/docs/start/explore-models',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-predict-image-classification-sample',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-cancel-batch-prediction-job-sample',
#  'https://cloud.google.com/vertex-ai/docs/general/custom-service-account',
#  'https://cloud.google.com/vertex-ai/docs/vizier/using-vizier',
#  'https://cloud.google.com/vertex-ai/docs/matching-engine/overview',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-create-training-pipeline-sample',
#  'https://cloud.google.com/vertex-ai/docs/evaluation/introduction',
#  'https://cloud.google.com/vertex-ai/docs/image-data/object-detection/prepare-data',
#  'https://cloud.google.com/vertex-ai/docs/training/train-nfs-share',
#  'https://cloud.google.com/vertex-ai/docs/generative-ai/image/base64-encode',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-create-dataset-image-sample',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-import-data-text-entity-extraction-sample',
#  'https://cloud.google.com/vertex-ai/docs/matching-engine/query-index-public-endpoint',
#  'https://cloud.google.com/vertex-ai/docs/workbench/managed/access-control',
#  'https://cloud.google.com/vertex-ai/docs/tabular-data/classification-explanations',
#  'https://cloud.google.com/vertex-ai/docs/text-data/sentiment-analysis/train-model',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-create-training-pipeline-text-entity-extraction-sample',
#  'https://cloud.google.com/vertex-ai/docs/tutorials/image-recognition-automl/cleanup',
#  'https://cloud.google.com/vertex-ai/docs/workbench/user-managed/iam',
#  'https://cloud.google.com/vertex-ai/docs/generative-ai/text/summarization-prompts',
#  'https://cloud.google.com/vertex-ai/docs/pipelines/introduction',
#  'https://cloud.google.com/vertex-ai/docs/workbench/user-managed/managing-notebooks-upgrades-and-dependencies',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-delete-hyperparameter-tuning-job-sample',
#  'https://cloud.google.com/vertex-ai/docs/experiments/user-journey/uj-model-training',
#  'https://cloud.google.com/vertex-ai/docs/export/export-model-tabular',
#  'https://cloud.google.com/vertex-ai/docs/workbench/managed/authentication',
#  'https://cloud.google.com/vertex-ai/docs/general/monitoring-security',
#  'https://cloud.google.com/vertex-ai/docs/tabular-data/classification-regression/overview',
#  'https://cloud.google.com/vertex-ai/docs/workbench/introduction',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-sdk-list-tuned-models',
#  'https://cloud.google.com/vertex-ai/docs/tutorials/video-classification-automl/deploy-predict',
#  'https://cloud.google.com/vertex-ai/docs/ml-metadata/managing-metadata',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-predict-custom-trained-model-sample',
#  'https://cloud.google.com/vertex-ai/docs/generative-ai/data-governance',
#  'https://cloud.google.com/vertex-ai/docs/workbench/managed/manage-access',
#  'https://cloud.google.com/vertex-ai/docs/training/using-private-ip',
#  'https://cloud.google.com/vertex-ai/docs/model-monitoring',
#  'https://cloud.google.com/vertex-ai/docs/tutorials/text-classification-automl/deploy-predict',
#  'https://cloud.google.com/vertex-ai/docs/training/training-with-tpu-vm',
#  'https://cloud.google.com/vertex-ai/docs/experiments/user-journey/uj-autologging',
#  'https://cloud.google.com/vertex-ai/docs/tabular-data/tabular-workflows/pricing',
#  'https://cloud.google.com/vertex-ai/docs/start/install-sdk',
#  'https://cloud.google.com/vertex-ai/docs/tutorials/tabular-automl/overview',
#  'https://cloud.google.com/vertex-ai/docs/text-data/sentiment-analysis/create-dataset',
#  'https://cloud.google.com/vertex-ai/docs/training/neural-architecture-search/pre-built-trainer',
#  'https://cloud.google.com/vertex-ai/docs/general/audit-logging',
#  'https://cloud.google.com/vertex-ai/docs/supported-frameworks-list',
#  'https://cloud.google.com/vertex-ai/docs/text-data/entity-extraction/get-predictions',
#  'https://cloud.google.com/vertex-ai/docs/general/ml-use',
#  'https://cloud.google.com/vertex-ai/docs/general/long-running-operations',
#  'https://cloud.google.com/vertex-ai/docs/training/configure-compute',
#  'https://cloud.google.com/vertex-ai/docs/tutorials/image-recognition-custom/serving',
#  'https://cloud.google.com/vertex-ai/docs/pipelines/email-notification-component',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-export-model-video-action-recognition-sample',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-create-training-pipeline-text-classification-sample',
#  'https://cloud.google.com/vertex-ai/docs/pipelines/schedule-cloud-scheduler',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-deploy-model-sample',
#  'https://cloud.google.com/vertex-ai/docs/training/neural-architecture-search/pyglove',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-create-training-pipeline-tabular-forecasting-sample',
#  'https://cloud.google.com/vertex-ai/docs/general/general-concepts',
#  'https://cloud.google.com/vertex-ai/docs/generative-ai/start/quickstarts/api-quickstart',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-get-model-evaluation-video-action-recognition-sample',
#  'https://cloud.google.com/vertex-ai/docs/matching-engine/match-eng-setup/format-structure',
#  'https://cloud.google.com/vertex-ai/docs/matching-engine/query-index-vpc',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-get-model-evaluation-image-classification-sample',
#  'https://cloud.google.com/vertex-ai/docs/video-data/object-tracking/interpret-results',
#  'https://cloud.google.com/vertex-ai/docs/model-registry/model-alias',
#  'https://cloud.google.com/vertex-ai/docs/workbench/managed/service-perimeter',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-create-hyperparameter-tuning-job-sample',
#  'https://cloud.google.com/vertex-ai/docs/general/supported-languages',
#  'https://cloud.google.com/vertex-ai/docs/workbench/user-managed/managing-notebooks-upgrades-and-dependencies-process',
#  'https://cloud.google.com/vertex-ai/docs/workbench/managed',
#  'https://cloud.google.com/vertex-ai/docs/tabular-data/forecasting/train-model',
#  'https://cloud.google.com/vertex-ai/docs/image-data/classification/get-predictions',
#  'https://cloud.google.com/vertex-ai/docs/workbench/reference',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-delete-endpoint-sample',
#  'https://cloud.google.com/vertex-ai/docs/start/pytorch',
#  'https://cloud.google.com/vertex-ai/docs/start/client-libraries',
#  'https://cloud.google.com/vertex-ai/docs/datasets/export-metadata-annotations',
#  'https://cloud.google.com/vertex-ai/docs/tabular-data/tabular-workflows/overview',
#  'https://cloud.google.com/vertex-ai/docs/workbench/managed/idle-shutdown',
#  'https://cloud.google.com/vertex-ai/docs/pipelines/batchprediction-component',
#  'https://cloud.google.com/vertex-ai/docs/datasets/delete-annotation-set',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-create-batch-prediction-job-text-sentiment-analysis-sample',
#  'https://cloud.google.com/vertex-ai/docs/model-registry/copy-model',
#  'https://cloud.google.com/vertex-ai/docs/experiments/run-training-job-experiments',
#  'https://cloud.google.com/vertex-ai/docs/workbench/user-managed/shut-down',
#  'https://cloud.google.com/vertex-ai/docs/matching-engine/monitor',
#  'https://cloud.google.com/vertex-ai/docs/workbench/managed/schedule-managed-notebooks-run-quickstart',
#  'https://cloud.google.com/vertex-ai/docs/generative-ai/text/text-overview',
#  'https://cloud.google.com/vertex-ai/docs/video-data/object-tracking/train-model',
#  'https://cloud.google.com/vertex-ai/docs/pipelines/build-own-components',
#  'https://cloud.google.com/vertex-ai/docs/start/predictions-guide',
#  'https://cloud.google.com/vertex-ai/docs/generative-ai/code/test-code-completion-prompts',
#  'https://cloud.google.com/vertex-ai/docs/workbench/user-managed/separate-operations-development-notebooks-use',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-import-data-text-classification-single-label-sample',
#  'https://cloud.google.com/vertex-ai/docs/featurestore/managing-features',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-create-data-labeling-job-video-sample',
#  'https://cloud.google.com/vertex-ai/docs/generative-ai/code/code-chat-prompts',
#  'https://cloud.google.com/vertex-ai/docs/pipelines/model-evaluation-component',
#  'https://cloud.google.com/vertex-ai/docs/tabular-data/bp-tabular',
#  'https://cloud.google.com/vertex-ai/docs/pipelines/artifact-types',
#  'https://cloud.google.com/vertex-ai/docs/training/neural-architecture-search/nas-client',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-get-model-evaluation-sample',
#  'https://cloud.google.com/vertex-ai/docs/training/overview',
#  'https://cloud.google.com/vertex-ai/docs/ml-metadata/analyzing',
#  'https://cloud.google.com/vertex-ai/docs/tabular-data/tabular-workflows/wide-and-deep-online-predictions',
#  'https://cloud.google.com/vertex-ai/docs/matching-engine/ann-service-overview',
#  'https://cloud.google.com/vertex-ai/docs/matching-engine/filtering',
#  'https://cloud.google.com/vertex-ai/docs/training/tensorboard-profiler',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-delete-data-labeling-job-sample',
#  'https://cloud.google.com/vertex-ai/docs/datasets/data-labeling-job',
#  'https://cloud.google.com/vertex-ai/docs/tabular-data/data-splits',
#  'https://cloud.google.com/vertex-ai/docs/workbench/user-managed/registering-legacy-notebooks',
#  'https://cloud.google.com/vertex-ai/docs/tabular-data/tabular-workflows/tabnet-batch-predictions',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-create-training-pipeline-image-object-detection-sample',
#  'https://cloud.google.com/vertex-ai/docs/workbench/managed/visualize-data',
#  'https://cloud.google.com/vertex-ai/docs/workbench/user-managed/audit-logging',
#  'https://cloud.google.com/vertex-ai/docs/tutorials/jupyter-notebooks',
#  'https://cloud.google.com/vertex-ai/docs/generative-ai/text/test-text-prompts',
#  'https://cloud.google.com/vertex-ai/docs/predictions/custom-container-requirements',
#  'https://cloud.google.com/vertex-ai/docs/python-sdk/use-vertex-ai-python-sdk',
#  'https://cloud.google.com/vertex-ai/docs/featurestore/source-data',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-upload-model-sample',
#  'https://cloud.google.com/vertex-ai/docs/video-data/action-recognition/prepare-data',
#  'https://cloud.google.com/vertex-ai/docs/workbench/managed/develop',
#  'https://cloud.google.com/vertex-ai/docs/evaluation/using-model-evaluation',
#  'https://cloud.google.com/vertex-ai/docs/training/neural-architecture-search/pytorch-efficient-training',
#  'https://cloud.google.com/vertex-ai/docs/tutorials/custom-training-pipelines/image-classification',
#  'https://cloud.google.com/vertex-ai/docs/workbench/notebook-solution',
#  'https://cloud.google.com/vertex-ai/docs/training/pre-built-containers',
#  'https://cloud.google.com/vertex-ai/docs/predictions/using-nvidia-triton',
#  'https://cloud.google.com/vertex-ai/docs/pipelines/request-gcp-machine-resources',
#  'https://cloud.google.com/vertex-ai/docs/generative-ai/text/extraction-prompts',
#  'https://cloud.google.com/vertex-ai/docs/pipelines/logging',
#  'https://cloud.google.com/vertex-ai/docs/tutorials/text-classification-automl/dataset',
#  'https://cloud.google.com/vertex-ai/docs/start/introduction-interfaces',
#  'https://cloud.google.com/vertex-ai/docs/support/getting-support',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-get-model-sample',
#  'https://cloud.google.com/vertex-ai/docs/pipelines/customjob-component',
#  'https://cloud.google.com/vertex-ai/docs/experiments/user-journey/uj-track-params-metrics-custom-training',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-import-data-video-object-tracking-sample',
#  'https://cloud.google.com/vertex-ai/docs/generative-ai/speech/text-to-speech',
#  'https://cloud.google.com/vertex-ai/docs/general/troubleshooting-workbench',
#  'https://cloud.google.com/vertex-ai/docs/featurestore',
#  'https://cloud.google.com/vertex-ai/docs/training-overview',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-create-batch-prediction-job-text-entity-extraction-sample',
#  'https://cloud.google.com/vertex-ai/docs/general/access-control',
#  'https://cloud.google.com/vertex-ai/docs/ml-metadata/custom-schemas',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-get-custom-job-sample',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-delete-batch-prediction-job-sample',
#  'https://cloud.google.com/vertex-ai/docs/experiments/user-journey/uj-get-started-vertex-ai-experiments',
#  'https://cloud.google.com/vertex-ai/docs/pipelines/configure-failure-policy',
#  'https://cloud.google.com/vertex-ai/docs/tutorials/video-classification-automl/cleanup',
#  'https://cloud.google.com/vertex-ai/docs/workbench/managed/visualize-data-bigquery',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-upload-model-explain-tabular-managed-container-sample',
#  'https://cloud.google.com/vertex-ai/docs/pipelines/configure-caching',
#  'https://cloud.google.com/vertex-ai/docs/start/training-methods',
#  'https://cloud.google.com/vertex-ai/docs/workbench/managed/versions',
#  'https://cloud.google.com/vertex-ai/docs/predictions/get-batch-predictions',
#  'https://cloud.google.com/vertex-ai/docs/training/create-custom-container',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-create-hyperparameter-tuning-job-python-package-sample',
#  'https://cloud.google.com/vertex-ai/docs/training/create-python-pre-built-container',
#  'https://cloud.google.com/vertex-ai/docs/workbench/user-managed/create-user-managed-notebooks-instance-console-quickstart',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-create-training-pipeline-custom-job-sample',
#  'https://cloud.google.com/vertex-ai/docs/tabular-data/tabular-workflows/tabnet-train',
#  'https://cloud.google.com/vertex-ai/docs/workbench/user-managed/authentication',
#  'https://cloud.google.com/vertex-ai/docs/text-data/classification/train-model',
#  'https://cloud.google.com/vertex-ai/docs/generative-ai/embeddings/get-image-embeddings',
#  'https://cloud.google.com/vertex-ai/docs/training/cloud-storage-file-system',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-delete-dataset-sample',
#  'https://cloud.google.com/vertex-ai/docs/workbench/user-managed/cmek',
#  'https://cloud.google.com/vertex-ai/docs/training/using-hyperparameter-tuning',
#  'https://cloud.google.com/vertex-ai/docs/model-registry/model-labels',
#  'https://cloud.google.com/vertex-ai/docs/workbench/user-managed/monitor-health',
#  'https://cloud.google.com/vertex-ai/docs/matching-engine/configuring-indexes',
#  'https://cloud.google.com/vertex-ai/docs/text-data/entity-extraction/evaluate-model',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-create-dataset-tabular-gcs-sample',
#  'https://cloud.google.com/vertex-ai/docs/datasets/overview',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-create-batch-prediction-job-text-classification-sample',
#  'https://cloud.google.com/vertex-ai/docs/matching-engine/deploy-index-public',
#  'https://cloud.google.com/vertex-ai/docs/release-notes',
#  'https://cloud.google.com/vertex-ai/docs/matching-engine/create-manage-index',
#  'https://cloud.google.com/vertex-ai/docs/tabular-data/forecasting/prepare-data',
#  'https://cloud.google.com/vertex-ai/docs/text-data/sentiment-analysis/prepare-data',
#  'https://cloud.google.com/vertex-ai/docs/video-data/classification/evaluate-model',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-create-training-pipeline-custom-training-managed-dataset-sample',
#  'https://cloud.google.com/vertex-ai/docs/experiments/tensorboard-overview',
#  'https://cloud.google.com/vertex-ai/docs/training/neural-architecture-search/overview',
#  'https://cloud.google.com/vertex-ai/docs/model-registry/model-details',
#  'https://cloud.google.com/vertex-ai/docs/generative-ai/code/code-models-overview',
#  'https://cloud.google.com/vertex-ai/docs/image-data/classification/train-model',
#  'https://cloud.google.com/vertex-ai/docs/pipelines/build-pipeline',
#  'https://cloud.google.com/vertex-ai/docs/image-data/classification/interpret-results',
#  'https://cloud.google.com/vertex-ai/docs/generative-ai/text/batch-prediction-genai',
#  'https://cloud.google.com/vertex-ai/docs/pipelines/gcpc-label-propagation',
#  'https://cloud.google.com/vertex-ai/docs/generative-ai/image/image-captioning',
#  'https://cloud.google.com/vertex-ai/docs/featurestore/ingesting-stream',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-import-data-video-classification-sample',
#  'https://cloud.google.com/vertex-ai/docs/tabular-data/classification-regression/get-online-predictions',
#  'https://cloud.google.com/vertex-ai/docs/generative-ai/embeddings/get-text-embeddings',
#  'https://cloud.google.com/vertex-ai/docs/generative-ai/code/code-completion-prompts',
#  'https://cloud.google.com/vertex-ai/docs/matching-engine/match-eng-setup/match-eng-setup',
#  'https://cloud.google.com/vertex-ai/docs/image-data/classification/prepare-data',
#  'https://cloud.google.com/vertex-ai/docs/workbench/managed/bigquery',
#  'https://cloud.google.com/vertex-ai/docs/tabular-data/tabular-workflows/wide-and-deep-batch-predictions',
#  'https://cloud.google.com/vertex-ai/docs/video-data/classification/interpret-results',
#  'https://cloud.google.com/vertex-ai/docs/training/exporting-model-artifacts',
#  'https://cloud.google.com/vertex-ai/docs/explainable-ai/visualization-settings-automl-icn',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-create-data-labeling-job-specialist-pool-sample',
#  'https://cloud.google.com/vertex-ai/docs/tabular-data/tabular101',
#  'https://cloud.google.com/vertex-ai/docs/workbench/managed/custom-container',
#  'https://cloud.google.com/vertex-ai/docs/timeseries-insights',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-predict-text-entity-extraction-sample',
#  'https://cloud.google.com/vertex-ai/docs/pipelines/secret-manager',
#  'https://cloud.google.com/vertex-ai/docs/tabular-data/tabular-workflows/e2e-automl-train',
#  'https://cloud.google.com/vertex-ai/docs/tabular-data/classification-regression/evaluate-model',
#  'https://cloud.google.com/vertex-ai/docs/workbench/release-notes',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-predict-tabular-regression-sample',
#  'https://cloud.google.com/vertex-ai/docs/experiments/user-journey/uj-custom-training-autologging',
#  'https://cloud.google.com/vertex-ai/docs/beginner/bqml',
#  'https://cloud.google.com/vertex-ai/docs/generative-ai/image/img-gen-prompt-guide',
#  'https://cloud.google.com/vertex-ai/docs/start/use-terraform-vertex-ai',
#  'https://cloud.google.com/vertex-ai/docs/generative-ai/chat/test-chat-prompts',
#  'https://cloud.google.com/vertex-ai/docs/model-registry/versioning',
#  'https://cloud.google.com/vertex-ai/docs/pipelines/configure-project',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-create-training-pipeline-text-sentiment-analysis-sample',
#  'https://cloud.google.com/vertex-ai/docs/matching-engine/update-rebuild-index',
#  'https://cloud.google.com/vertex-ai/docs/start/ai-platform-users',
#  'https://cloud.google.com/vertex-ai/docs/text-data/classification/prepare-data',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-get-training-pipeline-sample',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-import-data-sample',
#  'https://cloud.google.com/vertex-ai/docs/model-registry/delete-model',
#  'https://cloud.google.com/vertex-ai/docs/experiments/tensorboard-training',
#  'https://cloud.google.com/vertex-ai/docs/tabular-data/forecasting-explanations',
#  'https://cloud.google.com/vertex-ai/docs/featurestore/serving-online',
#  'https://cloud.google.com/vertex-ai/docs/model-registry/import-model',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-export-model-tabular-classification-sample',
#  'https://cloud.google.com/vertex-ai/docs/resources',
#  'https://cloud.google.com/vertex-ai/sla/index-20210518',
#  'https://cloud.google.com/vertex-ai/docs/workbench/user-managed/manage-hardware-accelerators',
#  'https://cloud.google.com/vertex-ai/docs/text-data/sentiment-analysis/evaluate-model',
#  'https://cloud.google.com/vertex-ai/docs/generative-ai/learn/responsible-ai',
#  'https://cloud.google.com/vertex-ai/docs/generative-ai/chat/chat-prompts',
#  'https://cloud.google.com/vertex-ai/docs/tabular-data/classification-regression/prepare-data',
#  'https://cloud.google.com/vertex-ai/docs/tutorials/tabular-bq-prediction/create-dataset',
#  'https://cloud.google.com/vertex-ai/docs/shared-responsibility',
#  'https://cloud.google.com/vertex-ai/docs/tutorials/tabular-bq-prediction/train-and-deploy-model',
#  'https://cloud.google.com/vertex-ai/docs/text-data/sentiment-analysis/get-predictions',
#  'https://cloud.google.com/vertex-ai/docs/tabular-data/forecasting/overview',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-upload-model-explain-image-managed-container-sample',
#  'https://cloud.google.com/vertex-ai/docs/workbench/user-managed/before-you-begin',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-cancel-training-pipeline-sample',
#  'https://cloud.google.com/vertex-ai/docs/pipelines/use-template-gallery',
#  'https://cloud.google.com/vertex-ai/docs/pipelines/use-components',
#  'https://cloud.google.com/vertex-ai/docs/datasets/label-using-console',
#  'https://cloud.google.com/vertex-ai/docs/predictions/pre-built-containers',
#  'https://cloud.google.com/vertex-ai/docs/glossary',
#  'https://cloud.google.com/vertex-ai/docs/workbench/managed/executor-parameters',
#  'https://cloud.google.com/vertex-ai/docs/start/cloud-environment',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-get-model-evaluation-text-sentiment-analysis-sample',
#  'https://cloud.google.com/vertex-ai/docs/general/base64',
#  'https://cloud.google.com/vertex-ai/docs/pipelines/output-html-md',
#  'https://cloud.google.com/vertex-ai/docs/experiments/setup',
#  'https://cloud.google.com/vertex-ai/docs/start/training-guide',
#  'https://cloud.google.com/vertex-ai/docs/workbench/user-managed/migrate',
#  'https://cloud.google.com/vertex-ai/docs/experiments/track-executions-artifacts',
#  'https://cloud.google.com/vertex-ai/docs/matching-engine/deploy-index',
#  'https://cloud.google.com/vertex-ai/docs/generative-ai/image/fine-tune-model',
#  'https://cloud.google.com/vertex-ai/docs/pipelines/create-pipeline-template',
#  'https://cloud.google.com/vertex-ai/docs/explainable-ai/improving-explanations',
#  'https://cloud.google.com/vertex-ai/docs/quotas',
#  'https://cloud.google.com/vertex-ai/docs/tabular-data/tabular-workflows/tabnet',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-create-training-pipeline-tabular-classification-sample',
#  'https://cloud.google.com/vertex-ai/docs/general/cmek',
#  'https://cloud.google.com/vertex-ai/docs/python-sdk/data-classes',
#  'https://cloud.google.com/vertex-ai/docs/pipelines/gcpc-list',
#  'https://cloud.google.com/vertex-ai/docs/explainable-ai/visualization-settings',
#  'https://cloud.google.com/vertex-ai/docs/beginner/beginners-guide',
#  'https://cloud.google.com/vertex-ai/docs/explainable-ai/configuring-explanations-feature-based',
#  'https://cloud.google.com/vertex-ai/docs/generative-ai/image/edit-images',
#  'https://cloud.google.com/vertex-ai/docs/support/billing-questions',
#  'https://cloud.google.com/vertex-ai/docs/pipelines/bigqueryml-component',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-cancel-custom-job-sample',
#  'https://cloud.google.com/vertex-ai/docs/vizier/overview',
#  'https://cloud.google.com/vertex-ai/docs/workbench/user-managed/create-new',
#  'https://cloud.google.com/vertex-ai/docs/model-monitoring/schemas',
#  'https://cloud.google.com/vertex-ai/docs/text-data/classification/interpret-results',
#  'https://cloud.google.com/vertex-ai/docs/workbench/managed/cloud-storage',
#  'https://cloud.google.com/vertex-ai/docs/video-data/classification/create-dataset',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-get-model-evaluation-text-classification-sample',
#  'https://cloud.google.com/vertex-ai/docs/image-data/object-detection/train-model',
#  'https://cloud.google.com/vertex-ai/docs/tutorials',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-create-data-labeling-job-sample',
#  'https://cloud.google.com/vertex-ai/docs/predictions/custom-prediction-routines',
#  'https://cloud.google.com/vertex-ai/docs/tabular-data/forecasting/get-predictions',
#  'https://cloud.google.com/vertex-ai/docs/workbench/managed/create-instance',
#  'https://cloud.google.com/vertex-ai/docs/pipelines/machine-types',
#  'https://cloud.google.com/vertex-ai/docs/featurestore/serving-batch',
#  'https://cloud.google.com/vertex-ai/docs/image-data/classification/create-dataset',
#  'https://cloud.google.com/vertex-ai/docs/pipelines/dataproc-component',
#  'https://cloud.google.com/vertex-ai/docs/model-registry/introduction',
#  'https://cloud.google.com/vertex-ai/docs/predictions/model-co-hosting',
#  'https://cloud.google.com/vertex-ai/docs/pipelines/components-quickstart',
#  'https://cloud.google.com/vertex-ai/docs/pipelines/understand-pipeline-cost-labels',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-deploy-model-custom-trained-model-sample',
#  'https://cloud.google.com/vertex-ai/docs/export',
#  'https://cloud.google.com/vertex-ai/docs/export/export-edge-model',
#  'https://cloud.google.com/vertex-ai/docs/tabular-data/tabular-workflows/wide-and-deep',
#  'https://cloud.google.com/vertex-ai/docs/workbench/user-managed/shielded-vm',
#  'https://cloud.google.com/vertex-ai/docs/training/code-requirements',
#  'https://cloud.google.com/vertex-ai/docs/predictions/get-online-predictions',
#  'https://cloud.google.com/vertex-ai/docs/generative-ai/start/quickstarts/quickstart',
#  'https://cloud.google.com/vertex-ai/docs/matching-engine/deploy-index-vpc',
#  'https://cloud.google.com/vertex-ai/docs/training/distributed-training',
#  'https://cloud.google.com/vertex-ai/docs/generative-ai/speech/speech-to-text',
#  'https://cloud.google.com/vertex-ai/docs/ml-metadata/tracking',
#  'https://cloud.google.com/vertex-ai/docs/workbench/user-managed/upgrade',
#  'https://cloud.google.com/vertex-ai/docs/general/hybrid-connectivity',
#  'https://cloud.google.com/vertex-ai/docs/tabular-data/forecasting/create-dataset',
#  'https://cloud.google.com/vertex-ai/docs/pipelines/email-notifications',
#  'https://cloud.google.com/vertex-ai/docs/pipelines/schedule-pipeline-run',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-create-training-pipeline-tabular-regression-sample',
#  'https://cloud.google.com/vertex-ai/docs/generative-ai/migrate-from-azure',
#  'https://cloud.google.com/vertex-ai/docs/generative-ai/learn/prompt-samples',
#  'https://cloud.google.com/vertex-ai/docs/featurestore/delete-feature-values',
#  'https://cloud.google.com/vertex-ai/docs/general/resource-naming',
#  'https://cloud.google.com/vertex-ai/docs/tabular-data/overview',
#  'https://cloud.google.com/vertex-ai/docs/pipelines',
#  'https://cloud.google.com/vertex-ai/docs/general/vpc-peering',
#  'https://cloud.google.com/vertex-ai/docs/training/automl-edge-console',
#  'https://cloud.google.com/vertex-ai/docs/training/neural-architecture-search/environment-setup',
#  'https://cloud.google.com/vertex-ai/docs/tutorials/image-recognition-automl/dataset',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-export-model-sample',
#  'https://cloud.google.com/vertex-ai/docs/start/introduction-unified-platform',
#  'https://cloud.google.com/vertex-ai/docs/generative-ai/enable-audit-logs',
#  'https://cloud.google.com/vertex-ai/docs/predictions/use-custom-container',
#  'https://cloud.google.com/vertex-ai/docs/pipelines/vertex-automl-component',
#  'https://cloud.google.com/vertex-ai/docs/workbench/managed/manage-access-jupyterlab',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-create-endpoint-sample',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-predict-text-classification-single-label-sample',
#  'https://cloud.google.com/vertex-ai/docs/experiments/user-journey/uj-compare-pipeline-runs',
#  'https://cloud.google.com/vertex-ai/docs/training/configure-container-settings',
#  'https://cloud.google.com/vertex-ai/docs/general/vpc-service-controls',
#  'https://cloud.google.com/vertex-ai/docs/featurestore/ingesting-batch',
#  'https://cloud.google.com/vertex-ai/docs/generative-ai/learn/model-versioning',
#  'https://cloud.google.com/vertex-ai/docs/workbench/user-managed/ssh-access',
#  'https://cloud.google.com/vertex-ai/docs/training/neural-architecture-search/search-spaces',
#  'https://cloud.google.com/vertex-ai/docs/general/deep-learning',
#  'https://cloud.google.com/vertex-ai/docs/ml-metadata/introduction',
#  'https://cloud.google.com/vertex-ai/docs/training/using-managed-datasets',
#  'https://cloud.google.com/vertex-ai/docs/experiments/add-pipelinerun-experiment',
#  'https://cloud.google.com/vertex-ai/docs/predictions/optimized-tensorflow-runtime',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-create-batch-prediction-job-bigquery-sample',
#  'https://cloud.google.com/vertex-ai',
#  'https://cloud.google.com/vertex-ai/docs/generative-ai/code/code-generation-prompts',
#  'https://cloud.google.com/vertex-ai/docs/tabular-data/forecasting-arima/overview',
#  'https://cloud.google.com/vertex-ai/docs/workbench/managed/networking',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-get-model-evaluation-slice-sample',
#  'https://cloud.google.com/vertex-ai/docs/training/neural-architecture-search/proxy-task-design',
#  'https://cloud.google.com/vertex-ai/docs/tutorials/image-recognition-automl/deploy-predict',
#  'https://cloud.google.com/vertex-ai/docs/workbench/user-managed/manage-access-jupyterlab',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-create-batch-prediction-job-video-action-recognition-sample',
#  'https://cloud.google.com/vertex-ai/docs/text-data/entity-extraction/train-model',
#  'https://cloud.google.com/vertex-ai/docs/workbench/user-managed/separate-operations-development-notebooks-deploy',
#  'https://cloud.google.com/vertex-ai/docs/tutorials/tabular-bq-prediction/prerequisites',
#  'https://cloud.google.com/vertex-ai/docs/generative-ai/text/classification-prompts',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-create-dataset-text-sample',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-create-training-pipeline-video-action-recognition-sample',
#  'https://cloud.google.com/vertex-ai/docs/start/tensorflow',
#  'https://cloud.google.com/vertex-ai/docs/text-data/classification/create-dataset',
#  'https://cloud.google.com/vertex-ai/docs/pipelines/model-endpoint-component',
#  'https://cloud.google.com/vertex-ai/docs/tutorials/text-classification-automl',
#  'https://cloud.google.com/vertex-ai/docs/start/migrating-to-vertex-ai',
#  'https://cloud.google.com/vertex-ai/docs/image-data/object-detection/get-predictions',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-predict-sample',
#  'https://cloud.google.com/vertex-ai/docs/workbench/user-managed/dependencies',
#  'https://cloud.google.com/vertex-ai/docs/featurestore/managing-featurestores',
#  'https://cloud.google.com/vertex-ai/docs/general/access-transparency',
#  'https://cloud.google.com/vertex-ai/docs/pipelines/hyperparameter-tuning-component',
#  'https://cloud.google.com/vertex-ai/docs/samples',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-import-data-video-action-recognition-sample',
#  'https://cloud.google.com/vertex-ai/docs/experiments/autolog-data',
#  'https://cloud.google.com/vertex-ai/docs/tabular-data/classification-regression/train-model',
#  'https://cloud.google.com/vertex-ai/docs/general/locations',
#  'https://cloud.google.com/vertex-ai/docs/start/introduction-mlops',
#  'https://cloud.google.com/vertex-ai/docs/experiments/compare-analyze-runs',
#  'https://cloud.google.com/vertex-ai/docs',
#  'https://cloud.google.com/vertex-ai/docs/image-data/classification/evaluate-model',
#  'https://cloud.google.com/vertex-ai/docs/tutorials/custom-training-pipelines/tabular',
#  'https://cloud.google.com/vertex-ai/docs/training/neural-architecture-search/suggested-workflow',
#  'https://cloud.google.com/vertex-ai/docs/featurestore/concepts',
#  'https://cloud.google.com/vertex-ai/sla/index-20211216',
#  'https://cloud.google.com/vertex-ai/docs/workbench/user-managed/separate-operations-development-notebooks-overview',
#  'https://cloud.google.com/vertex-ai/docs/tabular-data/tabular-workflows/e2e-automl',
#  'https://cloud.google.com/vertex-ai/docs/workbench/managed/dataproc',
#  'https://cloud.google.com/vertex-ai/docs/generative-ai/image/generate-images',
#  'https://cloud.google.com/vertex-ai/docs/predictions/get-predictions',
#  'https://cloud.google.com/vertex-ai/docs/workbench/user-managed',
#  'https://cloud.google.com/vertex-ai/docs/generative-ai/learn/models',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-create-dataset-sample',
#  'https://cloud.google.com/vertex-ai/docs/workbench/user-managed/r-python-same-notebook',
#  'https://cloud.google.com/vertex-ai/docs/general/developer-tools-overview',
#  'https://cloud.google.com/vertex-ai/docs/workbench/managed/audit-logging',
#  'https://cloud.google.com/vertex-ai/docs/tabular-data/tabular-workflows/wide-and-deep-train',
#  'https://cloud.google.com/vertex-ai/docs/experiments/user-journey/uj-delete-outdated-tb-experiments',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-cancel-data-labeling-job-sample',
#  'https://cloud.google.com/vertex-ai/docs/experiments/log-models-exp-run',
#  'https://cloud.google.com/vertex-ai/docs/generative-ai/learn/overview',
#  'https://cloud.google.com/vertex-ai/docs/workbench/managed/migrate',
#  'https://cloud.google.com/vertex-ai/docs/explainable-ai/configuring-explanations-example-based',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-create-data-labeling-job-image-segmentation-sample',
#  'https://cloud.google.com/vertex-ai/docs/generative-ai/code/test-code-chat-prompts',
#  'https://cloud.google.com/vertex-ai/docs/reference',
#  'https://cloud.google.com/vertex-ai/pricing',
#  'https://cloud.google.com/vertex-ai/docs/tutorials/text-classification-automl/training',
#  'https://cloud.google.com/vertex-ai/docs/workbench/user-managed/custom-container',
#  'https://cloud.google.com/vertex-ai/docs/tabular-data/forecasting-prophet',
#  'https://cloud.google.com/vertex-ai/docs/generative-ai/image/visual-question-answering',
#  'https://cloud.google.com/vertex-ai/docs/generative-ai/access-control',
#  'https://cloud.google.com/vertex-ai/docs/image-data/object-detection/evaluate-model',
#  'https://cloud.google.com/vertex-ai/docs/tutorials/tabular-bq-prediction/create-notebook',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-get-model-evaluation-image-object-detection-sample',
#  'https://cloud.google.com/vertex-ai/docs/general/troubleshooting',
#  'https://cloud.google.com/vertex-ai/docs/featurestore/resource-policy',
#  'https://cloud.google.com/vertex-ai/docs/tabular-data/tabular-workflows/feature-engineering',
#  'https://cloud.google.com/vertex-ai/docs/generative-ai/learn/generative-ai-studio',
#  'https://cloud.google.com/vertex-ai/docs/video-data/action-recognition/create-dataset',
#  'https://cloud.google.com/vertex-ai/docs/tabular-data/forecasting/hierarchical',
#  'https://cloud.google.com/vertex-ai/docs/workbench/user-managed/save-to-github',
#  'https://cloud.google.com/vertex-ai/docs/predictions/using-private-endpoints',
#  'https://cloud.google.com/vertex-ai/docs/featurestore/export-features',
#  'https://cloud.google.com/vertex-ai/docs/general/monitoring-metrics',
#  'https://cloud.google.com/vertex-ai/docs/featurestore/overview',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-create-custom-job-sample',
#  'https://cloud.google.com/vertex-ai/docs/video-data/object-tracking/get-predictions',
#  'https://cloud.google.com/vertex-ai/docs/training/monitor-debug-interactive-shell',
#  'https://cloud.google.com/vertex-ai/docs/workbench/user-managed/introduction',
#  'https://cloud.google.com/vertex-ai/docs/ml-metadata',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-get-model-evaluation-video-classification-sample',
#  'https://cloud.google.com/vertex-ai/docs/explainable-ai/improve-explanations-automl-icn',
#  'https://cloud.google.com/vertex-ai/docs/featurestore/monitoring',
#  'https://cloud.google.com/vertex-ai/docs/text-data/classification/evaluate-model',
#  'https://cloud.google.com/vertex-ai/docs/workbench/managed/executor',
#  'https://cloud.google.com/vertex-ai/docs/matching-engine/support',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-import-data-image-object-detection-sample',
#  'https://cloud.google.com/vertex-ai/docs/workbench/user-managed/use-r-bigquery',
#  'https://cloud.google.com/vertex-ai/docs/python-sdk/model-classes',
#  'https://cloud.google.com/vertex-ai/docs/generative-ai/image/usage-guidelines',
#  'https://cloud.google.com/vertex-ai/docs/model-monitoring/model-monitoring-batch-predictions',
#  'https://cloud.google.com/vertex-ai/docs/pipelines/run-pipeline',
#  'https://cloud.google.com/vertex-ai/docs/video-data/object-tracking/create-dataset',
#  'https://cloud.google.com/vertex-ai/docs/tutorials/tabular-bq-prediction/make-prediction',
#  'https://cloud.google.com/vertex-ai/docs/tutorials/image-recognition-custom/training',
#  'https://cloud.google.com/vertex-ai/docs/featurestore/best-practices',
#  'https://cloud.google.com/vertex-ai/docs/workbench/managed/change-machine-type',
#  'https://cloud.google.com/vertex-ai/docs/tutorials/video-classification-automl',
#  'https://cloud.google.com/vertex-ai/docs/workbench/user-managed/separate-operations-development-notebooks-troubleshooting',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-create-batch-prediction-job-video-classification-sample',
#  'https://cloud.google.com/vertex-ai/docs/model-monitoring/overview',
#  'https://cloud.google.com/vertex-ai/docs/predictions/configure-compute',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-get-model-evaluation-text-entity-extraction-sample',
#  'https://cloud.google.com/vertex-ai/docs/ml-metadata/configure',
#  'https://cloud.google.com/vertex-ai/docs/matching-engine/faqs',
#  'https://cloud.google.com/vertex-ai/docs/matching-engine/match-eng-setup/vpc',
#  'https://cloud.google.com/vertex-ai/docs/python-sdk/python-sdk-class-overview',
#  'https://cloud.google.com/vertex-ai/docs/model-monitoring/using-model-monitoring',
#  'https://cloud.google.com/vertex-ai/docs/tabular-data/tabular-workflows/tabnet-online-predictions',
#  'https://cloud.google.com/vertex-ai/docs/tabular-data/classification-regression/logging',
#  'https://cloud.google.com/vertex-ai/docs/tabular-data/classification-regression/get-batch-predictions',
#  'https://cloud.google.com/vertex-ai/docs/ml-metadata/system-schemas',
#  'https://cloud.google.com/vertex-ai/docs/training/create-training-pipeline',
#  'https://cloud.google.com/vertex-ai/docs/training/containerize-run-code-local',
#  'https://cloud.google.com/vertex-ai/docs/video-data/action-recognition/interpret-results',
#  'https://cloud.google.com/vertex-ai/docs/tutorials/text-classification-automl/cleanup',
#  'https://cloud.google.com/vertex-ai/docs/general/features',
#  'https://cloud.google.com/vertex-ai/docs/workbench/notebooks',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-list-model-evaluation-slices-sample',
#  'https://cloud.google.com/vertex-ai/docs/start/migrating-applications',
#  'https://cloud.google.com/vertex-ai/docs/tutorials/tabular-automl/setup',
#  'https://cloud.google.com/vertex-ai/docs/workbench/user-managed/manage-access',
#  'https://cloud.google.com/vertex-ai/docs/image-data/object-detection/interpret-results',
#  'https://cloud.google.com/vertex-ai/docs/workbench/user-managed/service-perimeter',
#  'https://cloud.google.com/vertex-ai/docs/text-data/entity-extraction/prepare-data',
#  'https://cloud.google.com/vertex-ai/docs/training/containers-overview',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-predict-image-object-detection-sample',
#  'https://cloud.google.com/vertex-ai/docs/text-data/entity-extraction/create-dataset',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-create-training-pipeline-video-object-tracking-sample',
#  'https://cloud.google.com/vertex-ai/docs/pipelines/components-introduction',
#  'https://cloud.google.com/vertex-ai/docs/explainable-ai',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-cancel-hyperparameter-tuning-job-sample',
#  'https://cloud.google.com/vertex-ai/docs/tutorials/tabular-bq-prediction/create-training-script',
#  'https://cloud.google.com/vertex-ai/docs/framework-support-policy',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-create-dataset-video-sample',
#  'https://cloud.google.com/vertex-ai/docs/workbench/managed/create-managed-notebooks-instance-console-quickstart',
#  'https://cloud.google.com/vertex-ai/docs/predictions/overview',
#  'https://cloud.google.com/vertex-ai/docs/video-data/classification/get-predictions',
#  'https://cloud.google.com/vertex-ai/docs/datasets/data-types-tabular',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-delete-training-pipeline-sample',
#  'https://cloud.google.com/vertex-ai/docs/tutorials/video-classification-automl/training',
#  'https://cloud.google.com/vertex-ai/docs/pipelines/lineage',
#  'https://cloud.google.com/vertex-ai/docs/video-data/action-recognition/train-model',
#  'https://cloud.google.com/vertex-ai/docs/video-data/object-tracking/evaluate-model',
#  'https://cloud.google.com/vertex-ai/docs/training/understanding-training-service',
#  'https://cloud.google.com/vertex-ai/docs/matching-engine/match-eng-setup/private-service-connect',
#  'https://cloud.google.com/vertex-ai/docs/pipelines/notebooks',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-delete-model-sample',
#  'https://cloud.google.com/vertex-ai/docs/pipelines/trigger-pubsub',
#  'https://cloud.google.com/vertex-ai/docs/tutorials/tabular-automl/cleanup',
#  'https://cloud.google.com/vertex-ai/docs/general/deployment',
#  'https://cloud.google.com/vertex-ai/docs/image-data/object-detection/create-dataset',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-create-data-labeling-job-images-sample',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-delete-custom-job-sample',
#  'https://cloud.google.com/vertex-ai/docs/workbench/user-managed/create-specific-version',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-create-dataset-tabular-bigquery-sample',
#  'https://cloud.google.com/vertex-ai/docs/tutorials/image-recognition-automl/error-analysis',
#  'https://cloud.google.com/vertex-ai/docs/pipelines/migrate-kfp',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-get-hyperparameter-tuning-job-sample',
#  'https://cloud.google.com/vertex-ai/docs/video-data/action-recognition/evaluate-model',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-get-model-evaluation-video-object-tracking-sample',
#  'https://cloud.google.com/vertex-ai/docs/experiments/create-experiment',
#  'https://cloud.google.com/vertex-ai/docs/video-data/classification/train-model',
#  'https://cloud.google.com/vertex-ai/docs/tutorials/image-recognition-custom/cleanup',
#  'https://cloud.google.com/vertex-ai/docs/workbench/managed/upgrade',
#  'https://cloud.google.com/vertex-ai/docs/ml-metadata/data-model',
#  'https://cloud.google.com/vertex-ai/docs/tutorials/tabular-automl/deploy-predict',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-create-data-labeling-job-active-learning-sample',
#  'https://cloud.google.com/vertex-ai/docs/tabular-data/classification-regression/create-dataset',
#  'https://cloud.google.com/vertex-ai/docs/generative-ai/image/overview',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-import-data-image-classification-single-label-sample',
#  'https://cloud.google.com/vertex-ai/docs/tabular-data/tabular-workflows/quotas',
#  'https://cloud.google.com/vertex-ai/docs/python-sdk/tracking-classes',
#  'https://cloud.google.com/vertex-ai/docs/tutorials/terraform/terraform-create-user-managed-notebooks-instance',
#  'https://cloud.google.com/vertex-ai/docs/tutorials/video-classification-automl/dataset',
#  'https://cloud.google.com/vertex-ai/docs/pipelines/visualize-pipeline',
#  'https://cloud.google.com/vertex-ai/docs/text-data/entity-extraction/interpret-results',
#  'https://cloud.google.com/vertex-ai/docs/python-sdk/prediction-classes',
#  'https://cloud.google.com/vertex-ai/docs/workbench/managed/introduction',
#  'https://cloud.google.com/vertex-ai/docs/samples/aiplatform-import-data-text-sentiment-analysis-sample']

# %%
len(sites_filtered)
# Out:
# 597

# %% [markdown]
# ## Load page content using LangChains UnstructuredURLLoader

# %%
from langchain.document_loaders import UnstructuredURLLoader
loader = UnstructuredURLLoader(urls=sites_filtered)
documents = loader.load()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.

# %%
documents[42]
# Out:
# Document(page_content='Home\n\nDocs\n\nVertex AI\n\nDocumentation\n\nGuides\n\nService accounts for Tabular Workflows\n\nStay organized with collections\n\nSave and categorize content based on your preferences.\n\nThis page explains the service accounts for the following Tabular Workflows:\n\nTabular Workflow for End-to-End AutoML\n\nTabular Workflow for TabNet\n\nTabular Workflow for Wide & Deep\n\nProphet\n\nARIMA+\n\nService accounts for Tabular Workflow for End-to-End AutoML\n\nThis workflow uses the following service accounts:\n\nService account for Vertex AI Pipelines\n\nThe service account that runs the pipeline\n\nPROJECT_NUMBER-compute@developer.gserviceaccount.com\n\nCompute Engine default service account\n\nYes\n\nService account for Dataflow worker\n\nThe service account that runs the Dataflow workers\n\nPROJECT_NUMBER-compute@developer.gserviceaccount.com\n\nCompute Engine default service account\n\nYes\n\nAI Platform Service Agent\n\nThe service account that runs the training containers.\n\nservice-PROJECT_NUMBER@gcp-sa-aiplatform.iam.gserviceaccount.com\n\nAI Platform Service Agent\n\nNo\n\nSome of the service accounts can be changed to an account of your choice. See\nTrain a model with End-to-End AutoML for instructions specific to Google Cloud console or the API.\n\nService account for Vertex AI Pipelines\n\nYou must grant the following roles to the service account for Vertex AI Pipelines in the pipeline project:\n\nVertex AI User\n\naiplatform.metadataStores.get allows the service account to create a pipeline job. aiplatform.models.upload allows the service account to upload the model.\n\nStorage Object Admin\n\nThe storage.objects.get and storage.objects.create permissions of Storage Object Admin allow the service account to access the bucket for the root directory of the pipeline job. The service account needs these permissions even if you are not using a Cloud Storage data source.\n\nDataflow Developer\n\ndataflow.jobs.create allow the service account to create Dataflow jobs during evaluation.\n\nService Account User\n\niam.serviceAccounts.actAs allows the Vertex AI Pipelines service account to act as the Dataflow worker service account during evaluation.\n\nService account for Dataflow worker\n\nYou must grant the following roles to the service account for Dataflow worker in the pipeline project:\n\nDataflow Worker\n\nThis role allows the service account to access the resources needed to run Dataflow jobs.\n\nStorage Object Admin\n\nThis role allows the service account to access Cloud Storage buckets. The service account needs these permissions even if you are not using a Cloud Storage data source. This role includes all of the permissions granted by the Storage Object Viewer role.\n\nYou must additionally grant the following roles to the Dataflow worker service account based on your data source type:\n\nStandard BigQuery table\n\nBigQuery Data Editor\n\nProject that runs the pipeline\n\nBigQuery Job User\n\nProject that runs the pipeline\n\nBigQuery Data Viewer\n\nProject that the table belongs to\n\nBigQuery view of a standard BigQuery table\n\nBigQuery Data Editor\n\nProject that runs the pipeline\n\nBigQuery Job User\n\nProject that runs the pipeline\n\nBigQuery Data Viewer\n\nProject that the view belongs to\n\nBigQuery Data Viewer\n\nProject that the table belongs to\n\nBigQuery external table that has a source Cloud Storage file\n\nBigQuery Data Editor\n\nProject that runs the pipeline\n\nBigQuery Job User\n\nProject that runs the pipeline\n\nBigQuery Data Viewer\n\nProject that the external table belongs to\n\nStorage Object Viewer\n\nProject that the source file belongs to\n\nBigQuery view of a BigQuery external table that has a source Cloud Storage file\n\nBigQuery Data Editor\n\nProject that runs the pipeline\n\nBigQuery Job User\n\nProject that runs the pipeline\n\nBigQuery Data Viewer\n\nProject that the view belongs to\n\nBigQuery Data Viewer\n\nProject that the external table belongs to\n\n ...

# %%
len(documents)

# %% [markdown]
# ## Chunking

# %%
from langchain.text_splitter import CharacterTextSplitter

text_splitter = CharacterTextSplitter(
    separator = "\n",
    chunk_size = 1000,
    chunk_overlap  = 100)

document_chunks = text_splitter.split_documents(documents)

print(f"Number documents {len(documents)}")
print(f"Number chunks {len(document_chunks)}")

document_chunks=[f"Context: {chunk.page_content} Source: {chunk.metadata['source']}" for chunk in document_chunks]
# Out:
# WARNING:langchain.text_splitter:Created a chunk of size 1787, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2986, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 2152, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1044, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1073, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1583, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1787, which is longer than the specified 1000
# WARNING:langchain.text_splitter:Created a chunk of size 1047, which is longer than the specified 1000
# Number documents 597
# Number chunks 5827

# %% [markdown]
# # Embeddings for documents

# %% [markdown]
# ## Create embedding for all document chunks

# %%
# !rm -rf ./documents
# !mkdir ./documents

# %%
import time
from langchain.embeddings import VertexAIEmbeddings
import pandas as pd
import json

def handle_quota_errors(func, *args, retry_delay=5,backoff_factor=2, **kwargs):
    retries = 0

    try:
      return func(*args, **kwargs)
    except Exception as e:
      print(f"error: {e}")
      retries += 1
      wait = retry_delay * (backoff_factor ** retries)
      time.sleep(wait)
      print("wait for {wait} seconds")


embeddings = VertexAIEmbeddings()

df = pd.DataFrame(document_chunks, columns =['text'])

index_embeddings = []

for index, doc in df.iterrows():
  print(f"Get embedding and write document for document {index} of {len(df)-1}")
  embedding = handle_quota_errors(embeddings.embed_query, doc['text'])

  if embedding is not None:

    doc_id=f"{index}.txt"
    embedding_dict = {
              "id": doc_id,
              "embedding": [str(value) for value in embedding],
    }
    index_embeddings.append(json.dumps(embedding_dict) + "\n")

    doc_id = f"{index}.txt"
    with open(f"documents/{doc_id}", "w") as document:
      document.write(doc['text'])


with open("embeddings.json", "w") as f:
    f.writelines(index_embeddings)
# Out:
# Streaming output truncated to the last 5000 lines.
# Get embedding and write document for document 827 of 5826
# Get embedding and write document for document 828 of 5826
# Get embedding and write document for document 829 of 5826
# Get embedding and write document for document 830 of 5826
# Get embedding and write document for document 831 of 5826
# Get embedding and write document for document 832 of 5826
# Get embedding and write document for document 833 of 5826
# Get embedding and write document for document 834 of 5826
# Get embedding and write document for document 835 of 5826
# Get embedding and write document for document 836 of 5826
# Get embedding and write document for document 837 of 5826
# Get embedding and write document for document 838 of 5826
# Get embedding and write document for document 839 of 5826
# Get embedding and write document for document 840 of 5826
# Get embedding and write document for document 841 of 5826
# Get embedding and write document for document 842 of 5826
# Get embedding and write document for document 843 of 5826
# Get embedding and write document for document 844 of 5826
# Get embedding and write document for document 845 of 5826
# Get embedding and write document for document 846 of 5826
# Get embedding and write document for document 847 of 5826
# Get embedding and write document for document 848 of 5826
# Get embedding and write document for document 849 of 5826
# Get embedding and write document for document 850 of 5826
# Get embedding and write document for document 851 of 5826
# Get embedding and write document for document 852 of 5826
# Get embedding and write document for document 853 of 5826
# Get embedding and write document for document 854 of 5826
# Get embedding and write document for document 855 of 5826
# Get embedding and write document for document 856 of 5826
# Get embedding and write document for document 857 of 5826
# Get embedding and write document for document 858 of 5826
# Get embedding and write document for document 859 of 5826
# Get embedding and write document for document 860 of 5826
# Get embedding and write document for document 861 of 5826
# Get embedding and write document for document 862 of 5826
# Get embedding and write document for document 863 of 5826
# Get embedding and write document for document 864 of 5826
# Get embedding and write document for document 865 of 5826
# Get embedding and write document for document 866 of 5826
# Get embedding and write document for document 867 of 5826
# Get embedding and write document for document 868 of 5826
# Get embedding and write document for document 869 of 5826
# Get embedding and write document for document 870 of 5826
# Get embedding and write document for document 871 of 5826
# Get embedding and write document for document 872 of 5826
# Get embedding and write document for document 873 of 5826
# Get embedding and write document for document 874 of 5826
# Get embedding and write document for document 875 of 5826
# Get embedding and write document for document 876 of 5826
# Get embedding and write document for document 877 of 5826
# Get embedding and write document for document 878 of 5826
# Get embedding and write document for document 879 of 5826
# Get embedding and write document for document 880 of 5826
# Get embedding and write document for document 881 of 5826
# Get embedding and write document for document 882 of 5826
# Get embedding and write document for document 883 of 5826
# Get embedding and write document for document 884 of 5826
# Get embedding and write document for document 885 of 5826
# Get embedding and write document for document 886 of 5826
# Get embedding and write document for document 887 of 5826
# Get embedding and write document for document 888 of 5826
# Get embedding and write document for document 889 of 5826
# Get embedding and write document for document 890 of 5826
# Get embedding and write document for document 891 of 5826
# Get embedding and write document for document 892 of 5826
# Get embedding and write document for document 893 of 5826
# Get embedding and write document for document 894 of 5826
# Get embedding and write document for document 895 of 5826
# Get embedding and write document for document 896 of 5826
# Get embedding and write document for document 897 of 5826
# Get embedding and write document for document 898 of 5826
# Get embedding and write document for document 899 of 5826
# Get embedding and write document for document 900 of 5826
# Get embedding and write document for document 901 of 5826
# Get embedding and write document for document 902 of 5826
# Get embedding and write document for document 903 of 5826
# Get embedding and write document for document 904 of 5826
# Get embedding and write document for document 905 of 5826
# Get embedding and write document for document 906 of 5826
# Get embedding and write document for document 907 of 5826
# Get embedding and write document for document 908 of 5826
# Get embedding and write document for document 909 of 5826
# Get embedding and write document for document 910 of 5826
# Get embedding and write document for document 911 of 5826
# Get embedding and write document for document 912 of 5826
# Get embedding and write document for document 913 of 5826
# Get embedding and write document for document 914 of 5826
# Get embedding and write document for document 915 of 5826
# Get embedding and write document for document 916 of 5826
# Get embedding and write document for document 917 of 5826
# Get embedding and write document for document 918 of 5826
# Get embedding and write document for document 919 of 5826
# Get embedding and write document for document 920 of 5826
# Get embedding and write document for document 921 of 5826
# Get embedding and write document for document 922 of 5826
# Get embedding and write document for document 923 of 5826
# Get embedding and write document for document 924 of 5826
# Get embedding and write document for document 925 of 5826
# Get embedding and write document for document 926 of 5826
# Get embedding and write document for document 927 of 5826
# Get embedding and write document for document 928 of 5826
# Get embedding and write document for document 929 of 5826
# Get embedding and write document for document 930 of 5826
# Get embedding and write document for document 931 of 5826
# Get embedding and write document for document 932 of 5826
# Get embedding and write document for document 933 of 5826
# Get embedding and write document for document 934 of 5826
# Get embedding and write document for document 935 of 5826
# Get embedding and write document for document 936 of 5826
# Get embedding and write document for document 937 of 5826
# Get embedding and write document for document 938 of 5826
# Get embedding and write document for document 939 of 5826
# Get embedding and write document for document 940 of 5826
# Get embedding and write document for document 941 of 5826
# Get embedding and write document for document 942 of 5826
# Get embedding and write document for document 943 of 5826
# Get embedding and write document for document 944 of 5826
# Get embedding and write document for document 945 of 5826
# Get embedding and write document for document 946 of 5826
# Get embedding and write document for document 947 of 5826
# Get embedding and write document for document 948 of 5826
# Get embedding and write document for document 949 of 5826
# Get embedding and write document for document 950 of 5826
# Get embedding and write document for document 951 of 5826
# Get embedding and write document for document 952 of 5826
# Get embedding and write document for document 953 of 5826
# Get embedding and write document for document 954 of 5826
# Get embedding and write document for document 955 of 5826
# Get embedding and write document for document 956 of 5826
# Get embedding and write document for document 957 of 5826
# Get embedding and write document for document 958 of 5826
# Get embedding and write document for document 959 of 5826
# Get embedding and write document for document 960 of 5826
# Get embedding and write document for document 961 of 5826
# Get embedding and write document for document 962 of 5826
# Get embedding and write document for document 963 of 5826
# Get embedding and write document for document 964 of 5826
# Get embedding and write document for document 965 of 5826
# Get embedding and write document for document 966 of 5826
# Get embedding and write document for document 967 of 5826
# Get embedding and write document for document 968 of 5826
# Get embedding and write document for document 969 of 5826
# Get embedding and write document for document 970 of 5826
# Get embedding and write document for document 971 of 5826
# Get embedding and write document for document 972 of 5826
# Get embedding and write document for document 973 of 5826
# Get embedding and write document for document 974 of 5826
# Get embedding and write document for document 975 of 5826
# Get embedding and write document for document 976 of 5826
# Get embedding and write document for document 977 of 5826
# Get embedding and write document for document 978 of 5826
# Get embedding and write document for document 979 of 5826
# Get embedding and write document for document 980 of 5826
# Get embedding and write document for document 981 of 5826
# Get embedding and write document for document 982 of 5826
# Get embedding and write document for document 983 of 5826
# Get embedding and write document for document 984 of 5826
# Get embedding and write document for document 985 of 5826
# Get embedding and write document for document 986 of 5826
# Get embedding and write document for document 987 of 5826
# Get embedding and write document for document 988 of 5826
# Get embedding and write document for document 989 of 5826
# Get embedding and write document for document 990 of 5826
# Get embedding and write document for document 991 of 5826
# Get embedding and write document for document 992 of 5826
# Get embedding and write document for document 993 of 5826
# Get embedding and write document for document 994 of 5826
# Get embedding and write document for document 995 of 5826
# Get embedding and write document for document 996 of 5826
# Get embedding and write document for document 997 of 5826
# Get embedding and write document for document 998 of 5826
# Get embedding and write document for document 999 of 5826
# Get embedding and write document for document 1000 of 5826
# Get embedding and write document for document 1001 of 5826
# Get embedding and write document for document 1002 of 5826
# Get embedding and write document for document 1003 of 5826
# Get embedding and write document for document 1004 of 5826
# Get embedding and write document for document 1005 of 5826
# Get embedding and write document for document 1006 of 5826
# Get embedding and write document for document 1007 of 5826
# Get embedding and write document for document 1008 of 5826
# Get embedding and write document for document 1009 of 5826
# Get embedding and write document for document 1010 of 5826
# Get embedding and write document for document 1011 of 5826
# Get embedding and write document for document 1012 of 5826
# Get embedding and write document for document 1013 of 5826
# Get embedding and write document for document 1014 of 5826
# Get embedding and write document for document 1015 of 5826
# Get embedding and write document for document 1016 of 5826
# Get embedding and write document for document 1017 of 5826
# Get embedding and write document for document 1018 of 5826
# Get embedding and write document for document 1019 of 5826
# Get embedding and write document for document 1020 of 5826
# Get embedding and write document for document 1021 of 5826
# Get embedding and write document for document 1022 of 5826
# Get embedding and write document for document 1023 of 5826
# Get embedding and write document for document 1024 of 5826
# Get embedding and write document for document 1025 of 5826
# Get embedding and write document for document 1026 of 5826
# Get embedding and write document for document 1027 of 5826
# Get embedding and write document for document 1028 of 5826
# Get embedding and write document for document 1029 of 5826
# Get embedding and write document for document 1030 of 5826
# Get embedding and write document for document 1031 of 5826
# Get embedding and write document for document 1032 of 5826
# Get embedding and write document for document 1033 of 5826
# Get embedding and write document for document 1034 of 5826
# Get embedding and write document for document 1035 of 5826
# Get embedding and write document for document 1036 of 5826
# Get embedding and write document for document 1037 of 5826
# Get embedding and write document for document 1038 of 5826
# Get embedding and write document for document 1039 of 5826
# Get embedding and write document for document 1040 of 5826
# Get embedding and write document for document 1041 of 5826
# Get embedding and write document for document 1042 of 5826
# Get embedding and write document for document 1043 of 5826
# Get embedding and write document for document 1044 of 5826
# Get embedding and write document for document 1045 of 5826
# Get embedding and write document for document 1046 of 5826
# Get embedding and write document for document 1047 of 5826
# Get embedding and write document for document 1048 of 5826
# Get embedding and write document for document 1049 of 5826
# Get embedding and write document for document 1050 of 5826
# Get embedding and write document for document 1051 of 5826
# Get embedding and write document for document 1052 of 5826
# Get embedding and write document for document 1053 of 5826
# Get embedding and write document for document 1054 of 5826
# Get embedding and write document for document 1055 of 5826
# Get embedding and write document for document 1056 of 5826
# Get embedding and write document for document 1057 of 5826
# Get embedding and write document for document 1058 of 5826
# Get embedding and write document for document 1059 of 5826
# Get embedding and write document for document 1060 of 5826
# Get embedding and write document for document 1061 of 5826
# Get embedding and write document for document 1062 of 5826
# Get embedding and write document for document 1063 of 5826
# Get embedding and write document for document 1064 of 5826
# Get embedding and write document for document 1065 of 5826
# Get embedding and write document for document 1066 of 5826
# Get embedding and write document for document 1067 of 5826
# Get embedding and write document for document 1068 of 5826
# Get embedding and write document for document 1069 of 5826
# Get embedding and write document for document 1070 of 5826
# Get embedding and write document for document 1071 of 5826
# Get embedding and write document for document 1072 of 5826
# Get embedding and write document for document 1073 of 5826
# Get embedding and write document for document 1074 of 5826
# Get embedding and write document for document 1075 of 5826
# Get embedding and write document for document 1076 of 5826
# Get embedding and write document for document 1077 of 5826
# Get embedding and write document for document 1078 of 5826
# Get embedding and write document for document 1079 of 5826
# Get embedding and write document for document 1080 of 5826
# Get embedding and write document for document 1081 of 5826
# Get embedding and write document for document 1082 of 5826
# Get embedding and write document for document 1083 of 5826
# Get embedding and write document for document 1084 of 5826
# Get embedding and write document for document 1085 of 5826
# Get embedding and write document for document 1086 of 5826
# Get embedding and write document for document 1087 of 5826
# Get embedding and write document for document 1088 of 5826
# Get embedding and write document for document 1089 of 5826
# Get embedding and write document for document 1090 of 5826
# Get embedding and write document for document 1091 of 5826
# Get embedding and write document for document 1092 of 5826
# Get embedding and write document for document 1093 of 5826
# Get embedding and write document for document 1094 of 5826
# Get embedding and write document for document 1095 of 5826
# Get embedding and write document for document 1096 of 5826
# Get embedding and write document for document 1097 of 5826
# Get embedding and write document for document 1098 of 5826
# Get embedding and write document for document 1099 of 5826
# Get embedding and write document for document 1100 of 5826
# Get embedding and write document for document 1101 of 5826
# Get embedding and write document for document 1102 of 5826
# Get embedding and write document for document 1103 of 5826
# Get embedding and write document for document 1104 of 5826
# Get embedding and write document for document 1105 of 5826
# Get embedding and write document for document 1106 of 5826
# Get embedding and write document for document 1107 of 5826
# Get embedding and write document for document 1108 of 5826
# Get embedding and write document for document 1109 of 5826
# Get embedding and write document for document 1110 of 5826
# Get embedding and write document for document 1111 of 5826
# Get embedding and write document for document 1112 of 5826
# Get embedding and write document for document 1113 of 5826
# Get embedding and write document for document 1114 of 5826
# Get embedding and write document for document 1115 of 5826
# Get embedding and write document for document 1116 of 5826
# Get embedding and write document for document 1117 of 5826
# Get embedding and write document for document 1118 of 5826
# Get embedding and write document for document 1119 of 5826
# Get embedding and write document for document 1120 of 5826
# Get embedding and write document for document 1121 of 5826
# Get embedding and write document for document 1122 of 5826
# Get embedding and write document for document 1123 of 5826
# Get embedding and write document for document 1124 of 5826
# Get embedding and write document for document 1125 of 5826
# Get embedding and write document for document 1126 of 5826
# Get embedding and write document for document 1127 of 5826
# Get embedding and write document for document 1128 of 5826
# Get embedding and write document for document 1129 of 5826
# Get embedding and write document for document 1130 of 5826
# Get embedding and write document for document 1131 of 5826
# Get embedding and write document for document 1132 of 5826
# Get embedding and write document for document 1133 of 5826
# Get embedding and write document for document 1134 of 5826
# Get embedding and write document for document 1135 of 5826
# Get embedding and write document for document 1136 of 5826
# Get embedding and write document for document 1137 of 5826
# Get embedding and write document for document 1138 of 5826
# Get embedding and write document for document 1139 of 5826
# Get embedding and write document for document 1140 of 5826
# Get embedding and write document for document 1141 of 5826
# Get embedding and write document for document 1142 of 5826
# Get embedding and write document for document 1143 of 5826
# Get embedding and write document for document 1144 of 5826
# Get embedding and write document for document 1145 of 5826
# Get embedding and write document for document 1146 of 5826
# Get embedding and write document for document 1147 of 5826
# Get embedding and write document for document 1148 of 5826
# Get embedding and write document for document 1149 of 5826
# Get embedding and write document for document 1150 of 5826
# Get embedding and write document for document 1151 of 5826
# Get embedding and write document for document 1152 of 5826
# Get embedding and write document for document 1153 of 5826
# Get embedding and write document for document 1154 of 5826
# Get embedding and write document for document 1155 of 5826
# Get embedding and write document for document 1156 of 5826
# Get embedding and write document for document 1157 of 5826
# Get embedding and write document for document 1158 of 5826
# Get embedding and write document for document 1159 of 5826
# Get embedding and write document for document 1160 of 5826
# Get embedding and write document for document 1161 of 5826
# Get embedding and write document for document 1162 of 5826
# Get embedding and write document for document 1163 of 5826
# Get embedding and write document for document 1164 of 5826
# Get embedding and write document for document 1165 of 5826
# Get embedding and write document for document 1166 of 5826
# Get embedding and write document for document 1167 of 5826
# Get embedding and write document for document 1168 of 5826
# Get embedding and write document for document 1169 of 5826
# Get embedding and write document for document 1170 of 5826
# Get embedding and write document for document 1171 of 5826
# Get embedding and write document for document 1172 of 5826
# Get embedding and write document for document 1173 of 5826
# Get embedding and write document for document 1174 of 5826
# Get embedding and write document for document 1175 of 5826
# Get embedding and write document for document 1176 of 5826
# Get embedding and write document for document 1177 of 5826
# Get embedding and write document for document 1178 of 5826
# Get embedding and write document for document 1179 of 5826
# Get embedding and write document for document 1180 of 5826
# Get embedding and write document for document 1181 of 5826
# Get embedding and write document for document 1182 of 5826
# Get embedding and write document for document 1183 of 5826
# Get embedding and write document for document 1184 of 5826
# Get embedding and write document for document 1185 of 5826
# Get embedding and write document for document 1186 of 5826
# Get embedding and write document for document 1187 of 5826
# Get embedding and write document for document 1188 of 5826
# Get embedding and write document for document 1189 of 5826
# Get embedding and write document for document 1190 of 5826
# Get embedding and write document for document 1191 of 5826
# Get embedding and write document for document 1192 of 5826
# Get embedding and write document for document 1193 of 5826
# Get embedding and write document for document 1194 of 5826
# Get embedding and write document for document 1195 of 5826
# Get embedding and write document for document 1196 of 5826
# Get embedding and write document for document 1197 of 5826
# Get embedding and write document for document 1198 of 5826
# Get embedding and write document for document 1199 of 5826
# Get embedding and write document for document 1200 of 5826
# Get embedding and write document for document 1201 of 5826
# Get embedding and write document for document 1202 of 5826
# Get embedding and write document for document 1203 of 5826
# Get embedding and write document for document 1204 of 5826
# Get embedding and write document for document 1205 of 5826
# Get embedding and write document for document 1206 of 5826
# Get embedding and write document for document 1207 of 5826
# Get embedding and write document for document 1208 of 5826
# Get embedding and write document for document 1209 of 5826
# Get embedding and write document for document 1210 of 5826
# Get embedding and write document for document 1211 of 5826
# Get embedding and write document for document 1212 of 5826
# Get embedding and write document for document 1213 of 5826
# Get embedding and write document for document 1214 of 5826
# Get embedding and write document for document 1215 of 5826
# Get embedding and write document for document 1216 of 5826
# Get embedding and write document for document 1217 of 5826
# Get embedding and write document for document 1218 of 5826
# Get embedding and write document for document 1219 of 5826
# Get embedding and write document for document 1220 of 5826
# Get embedding and write document for document 1221 of 5826
# Get embedding and write document for document 1222 of 5826
# Get embedding and write document for document 1223 of 5826
# Get embedding and write document for document 1224 of 5826
# Get embedding and write document for document 1225 of 5826
# Get embedding and write document for document 1226 of 5826
# Get embedding and write document for document 1227 of 5826
# Get embedding and write document for document 1228 of 5826
# Get embedding and write document for document 1229 of 5826
# Get embedding and write document for document 1230 of 5826
# Get embedding and write document for document 1231 of 5826
# Get embedding and write document for document 1232 of 5826
# Get embedding and write document for document 1233 of 5826
# Get embedding and write document for document 1234 of 5826
# Get embedding and write document for document 1235 of 5826
# Get embedding and write document for document 1236 of 5826
# Get embedding and write document for document 1237 of 5826
# Get embedding and write document for document 1238 of 5826
# Get embedding and write document for document 1239 of 5826
# Get embedding and write document for document 1240 of 5826
# Get embedding and write document for document 1241 of 5826
# Get embedding and write document for document 1242 of 5826
# Get embedding and write document for document 1243 of 5826
# Get embedding and write document for document 1244 of 5826
# Get embedding and write document for document 1245 of 5826
# Get embedding and write document for document 1246 of 5826
# Get embedding and write document for document 1247 of 5826
# Get embedding and write document for document 1248 of 5826
# Get embedding and write document for document 1249 of 5826
# Get embedding and write document for document 1250 of 5826
# Get embedding and write document for document 1251 of 5826
# Get embedding and write document for document 1252 of 5826
# Get embedding and write document for document 1253 of 5826
# Get embedding and write document for document 1254 of 5826
# Get embedding and write document for document 1255 of 5826
# Get embedding and write document for document 1256 of 5826
# Get embedding and write document for document 1257 of 5826
# Get embedding and write document for document 1258 of 5826
# Get embedding and write document for document 1259 of 5826
# Get embedding and write document for document 1260 of 5826
# Get embedding and write document for document 1261 of 5826
# Get embedding and write document for document 1262 of 5826
# Get embedding and write document for document 1263 of 5826
# Get embedding and write document for document 1264 of 5826
# Get embedding and write document for document 1265 of 5826
# Get embedding and write document for document 1266 of 5826
# Get embedding and write document for document 1267 of 5826
# Get embedding and write document for document 1268 of 5826
# Get embedding and write document for document 1269 of 5826
# Get embedding and write document for document 1270 of 5826
# Get embedding and write document for document 1271 of 5826
# Get embedding and write document for document 1272 of 5826
# Get embedding and write document for document 1273 of 5826
# Get embedding and write document for document 1274 of 5826
# Get embedding and write document for document 1275 of 5826
# Get embedding and write document for document 1276 of 5826
# Get embedding and write document for document 1277 of 5826
# Get embedding and write document for document 1278 of 5826
# Get embedding and write document for document 1279 of 5826
# Get embedding and write document for document 1280 of 5826
# Get embedding and write document for document 1281 of 5826
# Get embedding and write document for document 1282 of 5826
# Get embedding and write document for document 1283 of 5826
# Get embedding and write document for document 1284 of 5826
# Get embedding and write document for document 1285 of 5826
# Get embedding and write document for document 1286 of 5826
# Get embedding and write document for document 1287 of 5826
# Get embedding and write document for document 1288 of 5826
# Get embedding and write document for document 1289 of 5826
# Get embedding and write document for document 1290 of 5826
# Get embedding and write document for document 1291 of 5826
# Get embedding and write document for document 1292 of 5826
# Get embedding and write document for document 1293 of 5826
# Get embedding and write document for document 1294 of 5826
# Get embedding and write document for document 1295 of 5826
# Get embedding and write document for document 1296 of 5826
# Get embedding and write document for document 1297 of 5826
# Get embedding and write document for document 1298 of 5826
# Get embedding and write document for document 1299 of 5826
# Get embedding and write document for document 1300 of 5826
# Get embedding and write document for document 1301 of 5826
# Get embedding and write document for document 1302 of 5826
# Get embedding and write document for document 1303 of 5826
# Get embedding and write document for document 1304 of 5826
# Get embedding and write document for document 1305 of 5826
# Get embedding and write document for document 1306 of 5826
# Get embedding and write document for document 1307 of 5826
# Get embedding and write document for document 1308 of 5826
# Get embedding and write document for document 1309 of 5826
# Get embedding and write document for document 1310 of 5826
# Get embedding and write document for document 1311 of 5826
# Get embedding and write document for document 1312 of 5826
# Get embedding and write document for document 1313 of 5826
# Get embedding and write document for document 1314 of 5826
# Get embedding and write document for document 1315 of 5826
# Get embedding and write document for document 1316 of 5826
# Get embedding and write document for document 1317 of 5826
# Get embedding and write document for document 1318 of 5826
# Get embedding and write document for document 1319 of 5826
# Get embedding and write document for document 1320 of 5826
# Get embedding and write document for document 1321 of 5826
# Get embedding and write document for document 1322 of 5826
# Get embedding and write document for document 1323 of 5826
# Get embedding and write document for document 1324 of 5826
# Get embedding and write document for document 1325 of 5826
# Get embedding and write document for document 1326 of 5826
# Get embedding and write document for document 1327 of 5826
# Get embedding and write document for document 1328 of 5826
# Get embedding and write document for document 1329 of 5826
# Get embedding and write document for document 1330 of 5826
# Get embedding and write document for document 1331 of 5826
# Get embedding and write document for document 1332 of 5826
# Get embedding and write document for document 1333 of 5826
# Get embedding and write document for document 1334 of 5826
# Get embedding and write document for document 1335 of 5826
# Get embedding and write document for document 1336 of 5826
# Get embedding and write document for document 1337 of 5826
# Get embedding and write document for document 1338 of 5826
# Get embedding and write document for document 1339 of 5826
# Get embedding and write document for document 1340 of 5826
# Get embedding and write document for document 1341 of 5826
# Get embedding and write document for document 1342 of 5826
# Get embedding and write document for document 1343 of 5826
# Get embedding and write document for document 1344 of 5826
# Get embedding and write document for document 1345 of 5826
# Get embedding and write document for document 1346 of 5826
# Get embedding and write document for document 1347 of 5826
# Get embedding and write document for document 1348 of 5826
# Get embedding and write document for document 1349 of 5826
# Get embedding and write document for document 1350 of 5826
# Get embedding and write document for document 1351 of 5826
# Get embedding and write document for document 1352 of 5826
# Get embedding and write document for document 1353 of 5826
# Get embedding and write document for document 1354 of 5826
# Get embedding and write document for document 1355 of 5826
# Get embedding and write document for document 1356 of 5826
# Get embedding and write document for document 1357 of 5826
# Get embedding and write document for document 1358 of 5826
# Get embedding and write document for document 1359 of 5826
# Get embedding and write document for document 1360 of 5826
# Get embedding and write document for document 1361 of 5826
# Get embedding and write document for document 1362 of 5826
# Get embedding and write document for document 1363 of 5826
# Get embedding and write document for document 1364 of 5826
# Get embedding and write document for document 1365 of 5826
# Get embedding and write document for document 1366 of 5826
# Get embedding and write document for document 1367 of 5826
# Get embedding and write document for document 1368 of 5826
# Get embedding and write document for document 1369 of 5826
# Get embedding and write document for document 1370 of 5826
# Get embedding and write document for document 1371 of 5826
# Get embedding and write document for document 1372 of 5826
# Get embedding and write document for document 1373 of 5826
# Get embedding and write document for document 1374 of 5826
# Get embedding and write document for document 1375 of 5826
# Get embedding and write document for document 1376 of 5826
# Get embedding and write document for document 1377 of 5826
# Get embedding and write document for document 1378 of 5826
# Get embedding and write document for document 1379 of 5826
# Get embedding and write document for document 1380 of 5826
# Get embedding and write document for document 1381 of 5826
# Get embedding and write document for document 1382 of 5826
# Get embedding and write document for document 1383 of 5826
# Get embedding and write document for document 1384 of 5826
# Get embedding and write document for document 1385 of 5826
# Get embedding and write document for document 1386 of 5826
# Get embedding and write document for document 1387 of 5826
# Get embedding and write document for document 1388 of 5826
# Get embedding and write document for document 1389 of 5826
# Get embedding and write document for document 1390 of 5826
# Get embedding and write document for document 1391 of 5826
# Get embedding and write document for document 1392 of 5826
# Get embedding and write document for document 1393 of 5826
# Get embedding and write document for document 1394 of 5826
# Get embedding and write document for document 1395 of 5826
# Get embedding and write document for document 1396 of 5826
# Get embedding and write document for document 1397 of 5826
# Get embedding and write document for document 1398 of 5826
# Get embedding and write document for document 1399 of 5826
# Get embedding and write document for document 1400 of 5826
# Get embedding and write document for document 1401 of 5826
# Get embedding and write document for document 1402 of 5826
# Get embedding and write document for document 1403 of 5826
# Get embedding and write document for document 1404 of 5826
# Get embedding and write document for document 1405 of 5826
# Get embedding and write document for document 1406 of 5826
# Get embedding and write document for document 1407 of 5826
# Get embedding and write document for document 1408 of 5826
# Get embedding and write document for document 1409 of 5826
# Get embedding and write document for document 1410 of 5826
# Get embedding and write document for document 1411 of 5826
# Get embedding and write document for document 1412 of 5826
# Get embedding and write document for document 1413 of 5826
# Get embedding and write document for document 1414 of 5826
# Get embedding and write document for document 1415 of 5826
# Get embedding and write document for document 1416 of 5826
# Get embedding and write document for document 1417 of 5826
# Get embedding and write document for document 1418 of 5826
# Get embedding and write document for document 1419 of 5826
# Get embedding and write document for document 1420 of 5826
# Get embedding and write document for document 1421 of 5826
# Get embedding and write document for document 1422 of 5826
# Get embedding and write document for document 1423 of 5826
# Get embedding and write document for document 1424 of 5826
# Get embedding and write document for document 1425 of 5826
# Get embedding and write document for document 1426 of 5826
# Get embedding and write document for document 1427 of 5826
# Get embedding and write document for document 1428 of 5826
# Get embedding and write document for document 1429 of 5826
# Get embedding and write document for document 1430 of 5826
# Get embedding and write document for document 1431 of 5826
# Get embedding and write document for document 1432 of 5826
# Get embedding and write document for document 1433 of 5826
# Get embedding and write document for document 1434 of 5826
# Get embedding and write document for document 1435 of 5826
# Get embedding and write document for document 1436 of 5826
# Get embedding and write document for document 1437 of 5826
# Get embedding and write document for document 1438 of 5826
# Get embedding and write document for document 1439 of 5826
# Get embedding and write document for document 1440 of 5826
# Get embedding and write document for document 1441 of 5826
# Get embedding and write document for document 1442 of 5826
# Get embedding and write document for document 1443 of 5826
# Get embedding and write document for document 1444 of 5826
# Get embedding and write document for document 1445 of 5826
# Get embedding and write document for document 1446 of 5826
# Get embedding and write document for document 1447 of 5826
# Get embedding and write document for document 1448 of 5826
# Get embedding and write document for document 1449 of 5826
# Get embedding and write document for document 1450 of 5826
# Get embedding and write document for document 1451 of 5826
# Get embedding and write document for document 1452 of 5826
# Get embedding and write document for document 1453 of 5826
# Get embedding and write document for document 1454 of 5826
# Get embedding and write document for document 1455 of 5826
# Get embedding and write document for document 1456 of 5826
# Get embedding and write document for document 1457 of 5826
# Get embedding and write document for document 1458 of 5826
# Get embedding and write document for document 1459 of 5826
# Get embedding and write document for document 1460 of 5826
# Get embedding and write document for document 1461 of 5826
# Get embedding and write document for document 1462 of 5826
# Get embedding and write document for document 1463 of 5826
# Get embedding and write document for document 1464 of 5826
# Get embedding and write document for document 1465 of 5826
# Get embedding and write document for document 1466 of 5826
# Get embedding and write document for document 1467 of 5826
# Get embedding and write document for document 1468 of 5826
# Get embedding and write document for document 1469 of 5826
# Get embedding and write document for document 1470 of 5826
# Get embedding and write document for document 1471 of 5826
# Get embedding and write document for document 1472 of 5826
# Get embedding and write document for document 1473 of 5826
# Get embedding and write document for document 1474 of 5826
# Get embedding and write document for document 1475 of 5826
# Get embedding and write document for document 1476 of 5826
# Get embedding and write document for document 1477 of 5826
# Get embedding and write document for document 1478 of 5826
# Get embedding and write document for document 1479 of 5826
# Get embedding and write document for document 1480 of 5826
# Get embedding and write document for document 1481 of 5826
# Get embedding and write document for document 1482 of 5826
# Get embedding and write document for document 1483 of 5826
# Get embedding and write document for document 1484 of 5826
# Get embedding and write document for document 1485 of 5826
# Get embedding and write document for document 1486 of 5826
# Get embedding and write document for document 1487 of 5826
# Get embedding and write document for document 1488 of 5826
# Get embedding and write document for document 1489 of 5826
# Get embedding and write document for document 1490 of 5826
# Get embedding and write document for document 1491 of 5826
# Get embedding and write document for document 1492 of 5826
# Get embedding and write document for document 1493 of 5826
# Get embedding and write document for document 1494 of 5826
# Get embedding and write document for document 1495 of 5826
# Get embedding and write document for document 1496 of 5826
# Get embedding and write document for document 1497 of 5826
# Get embedding and write document for document 1498 of 5826
# Get embedding and write document for document 1499 of 5826
# Get embedding and write document for document 1500 of 5826
# Get embedding and write document for document 1501 of 5826
# Get embedding and write document for document 1502 of 5826
# Get embedding and write document for document 1503 of 5826
# Get embedding and write document for document 1504 of 5826
# Get embedding and write document for document 1505 of 5826
# Get embedding and write document for document 1506 of 5826
# Get embedding and write document for document 1507 of 5826
# Get embedding and write document for document 1508 of 5826
# Get embedding and write document for document 1509 of 5826
# Get embedding and write document for document 1510 of 5826
# Get embedding and write document for document 1511 of 5826
# Get embedding and write document for document 1512 of 5826
# Get embedding and write document for document 1513 of 5826
# Get embedding and write document for document 1514 of 5826
# Get embedding and write document for document 1515 of 5826
# Get embedding and write document for document 1516 of 5826
# Get embedding and write document for document 1517 of 5826
# Get embedding and write document for document 1518 of 5826
# Get embedding and write document for document 1519 of 5826
# Get embedding and write document for document 1520 of 5826
# Get embedding and write document for document 1521 of 5826
# Get embedding and write document for document 1522 of 5826
# Get embedding and write document for document 1523 of 5826
# Get embedding and write document for document 1524 of 5826
# Get embedding and write document for document 1525 of 5826
# Get embedding and write document for document 1526 of 5826
# Get embedding and write document for document 1527 of 5826
# Get embedding and write document for document 1528 of 5826
# Get embedding and write document for document 1529 of 5826
# Get embedding and write document for document 1530 of 5826
# Get embedding and write document for document 1531 of 5826
# Get embedding and write document for document 1532 of 5826
# Get embedding and write document for document 1533 of 5826
# Get embedding and write document for document 1534 of 5826
# Get embedding and write document for document 1535 of 5826
# Get embedding and write document for document 1536 of 5826
# Get embedding and write document for document 1537 of 5826
# Get embedding and write document for document 1538 of 5826
# Get embedding and write document for document 1539 of 5826
# Get embedding and write document for document 1540 of 5826
# Get embedding and write document for document 1541 of 5826
# Get embedding and write document for document 1542 of 5826
# Get embedding and write document for document 1543 of 5826
# Get embedding and write document for document 1544 of 5826
# Get embedding and write document for document 1545 of 5826
# Get embedding and write document for document 1546 of 5826
# Get embedding and write document for document 1547 of 5826
# Get embedding and write document for document 1548 of 5826
# Get embedding and write document for document 1549 of 5826
# Get embedding and write document for document 1550 of 5826
# Get embedding and write document for document 1551 of 5826
# Get embedding and write document for document 1552 of 5826
# Get embedding and write document for document 1553 of 5826
# Get embedding and write document for document 1554 of 5826
# Get embedding and write document for document 1555 of 5826
# Get embedding and write document for document 1556 of 5826
# Get embedding and write document for document 1557 of 5826
# Get embedding and write document for document 1558 of 5826
# Get embedding and write document for document 1559 of 5826
# Get embedding and write document for document 1560 of 5826
# Get embedding and write document for document 1561 of 5826
# Get embedding and write document for document 1562 of 5826
# Get embedding and write document for document 1563 of 5826
# Get embedding and write document for document 1564 of 5826
# Get embedding and write document for document 1565 of 5826
# Get embedding and write document for document 1566 of 5826
# Get embedding and write document for document 1567 of 5826
# Get embedding and write document for document 1568 of 5826
# Get embedding and write document for document 1569 of 5826
# Get embedding and write document for document 1570 of 5826
# Get embedding and write document for document 1571 of 5826
# Get embedding and write document for document 1572 of 5826
# Get embedding and write document for document 1573 of 5826
# Get embedding and write document for document 1574 of 5826
# Get embedding and write document for document 1575 of 5826
# Get embedding and write document for document 1576 of 5826
# Get embedding and write document for document 1577 of 5826
# Get embedding and write document for document 1578 of 5826
# Get embedding and write document for document 1579 of 5826
# Get embedding and write document for document 1580 of 5826
# Get embedding and write document for document 1581 of 5826
# Get embedding and write document for document 1582 of 5826
# Get embedding and write document for document 1583 of 5826
# Get embedding and write document for document 1584 of 5826
# Get embedding and write document for document 1585 of 5826
# Get embedding and write document for document 1586 of 5826
# Get embedding and write document for document 1587 of 5826
# Get embedding and write document for document 1588 of 5826
# Get embedding and write document for document 1589 of 5826
# Get embedding and write document for document 1590 of 5826
# Get embedding and write document for document 1591 of 5826
# Get embedding and write document for document 1592 of 5826
# Get embedding and write document for document 1593 of 5826
# Get embedding and write document for document 1594 of 5826
# Get embedding and write document for document 1595 of 5826
# Get embedding and write document for document 1596 of 5826
# Get embedding and write document for document 1597 of 5826
# Get embedding and write document for document 1598 of 5826
# Get embedding and write document for document 1599 of 5826
# Get embedding and write document for document 1600 of 5826
# Get embedding and write document for document 1601 of 5826
# Get embedding and write document for document 1602 of 5826
# Get embedding and write document for document 1603 of 5826
# Get embedding and write document for document 1604 of 5826
# Get embedding and write document for document 1605 of 5826
# Get embedding and write document for document 1606 of 5826
# Get embedding and write document for document 1607 of 5826
# Get embedding and write document for document 1608 of 5826
# Get embedding and write document for document 1609 of 5826
# Get embedding and write document for document 1610 of 5826
# Get embedding and write document for document 1611 of 5826
# Get embedding and write document for document 1612 of 5826
# Get embedding and write document for document 1613 of 5826
# Get embedding and write document for document 1614 of 5826
# Get embedding and write document for document 1615 of 5826
# Get embedding and write document for document 1616 of 5826
# Get embedding and write document for document 1617 of 5826
# Get embedding and write document for document 1618 of 5826
# Get embedding and write document for document 1619 of 5826
# Get embedding and write document for document 1620 of 5826
# Get embedding and write document for document 1621 of 5826
# Get embedding and write document for document 1622 of 5826
# Get embedding and write document for document 1623 of 5826
# Get embedding and write document for document 1624 of 5826
# Get embedding and write document for document 1625 of 5826
# Get embedding and write document for document 1626 of 5826
# Get embedding and write document for document 1627 of 5826
# Get embedding and write document for document 1628 of 5826
# Get embedding and write document for document 1629 of 5826
# Get embedding and write document for document 1630 of 5826
# Get embedding and write document for document 1631 of 5826
# Get embedding and write document for document 1632 of 5826
# Get embedding and write document for document 1633 of 5826
# Get embedding and write document for document 1634 of 5826
# Get embedding and write document for document 1635 of 5826
# Get embedding and write document for document 1636 of 5826
# Get embedding and write document for document 1637 of 5826
# Get embedding and write document for document 1638 of 5826
# Get embedding and write document for document 1639 of 5826
# Get embedding and write document for document 1640 of 5826
# Get embedding and write document for document 1641 of 5826
# ...
# Get embedding and write document for document 5556 of 5826
# Get embedding and write document for document 5557 of 5826
# Get embedding and write document for document 5558 of 5826
# Get embedding and write document for document 5559 of 5826
# Get embedding and write document for document 5560 of 5826
# Get embedding and write document for document 5561 of 5826
# Get embedding and write document for document 5562 of 5826
# Get embedding and write document for document 5563 of 5826
# Get embedding and write document for document 5564 of 5826
# Get embedding and write document for document 5565 of 5826
# Get embedding and write document for document 5566 of 5826
# Get embedding and write document for document 5567 of 5826
# Get embedding and write document for document 5568 of 5826
# Get embedding and write document for document 5569 of 5826
# Get embedding and write document for document 5570 of 5826
# Get embedding and write document for document 5571 of 5826
# Get embedding and write document for document 5572 of 5826
# Get embedding and write document for document 5573 of 5826
# Get embedding and write document for document 5574 of 5826
# Get embedding and write document for document 5575 of 5826
# Get embedding and write document for document 5576 of 5826
# Get embedding and write document for document 5577 of 5826
# Get embedding and write document for document 5578 of 5826
# Get embedding and write document for document 5579 of 5826
# Get embedding and write document for document 5580 of 5826
# Get embedding and write document for document 5581 of 5826
# Get embedding and write document for document 5582 of 5826
# Get embedding and write document for document 5583 of 5826
# Get embedding and write document for document 5584 of 5826
# Get embedding and write document for document 5585 of 5826
# Get embedding and write document for document 5586 of 5826
# Get embedding and write document for document 5587 of 5826
# Get embedding and write document for document 5588 of 5826
# Get embedding and write document for document 5589 of 5826
# Get embedding and write document for document 5590 of 5826
# Get embedding and write document for document 5591 of 5826
# Get embedding and write document for document 5592 of 5826
# Get embedding and write document for document 5593 of 5826
# Get embedding and write document for document 5594 of 5826
# Get embedding and write document for document 5595 of 5826
# Get embedding and write document for document 5596 of 5826
# Get embedding and write document for document 5597 of 5826
# Get embedding and write document for document 5598 of 5826
# Get embedding and write document for document 5599 of 5826
# Get embedding and write document for document 5600 of 5826
# Get embedding and write document for document 5601 of 5826
# Get embedding and write document for document 5602 of 5826
# Get embedding and write document for document 5603 of 5826
# Get embedding and write document for document 5604 of 5826
# Get embedding and write document for document 5605 of 5826
# Get embedding and write document for document 5606 of 5826
# Get embedding and write document for document 5607 of 5826
# Get embedding and write document for document 5608 of 5826
# Get embedding and write document for document 5609 of 5826
# Get embedding and write document for document 5610 of 5826
# Get embedding and write document for document 5611 of 5826
# Get embedding and write document for document 5612 of 5826
# Get embedding and write document for document 5613 of 5826
# Get embedding and write document for document 5614 of 5826
# Get embedding and write document for document 5615 of 5826
# Get embedding and write document for document 5616 of 5826
# Get embedding and write document for document 5617 of 5826
# Get embedding and write document for document 5618 of 5826
# Get embedding and write document for document 5619 of 5826
# Get embedding and write document for document 5620 of 5826
# Get embedding and write document for document 5621 of 5826
# Get embedding and write document for document 5622 of 5826
# Get embedding and write document for document 5623 of 5826
# Get embedding and write document for document 5624 of 5826
# Get embedding and write document for document 5625 of 5826
# Get embedding and write document for document 5626 of 5826
# Get embedding and write document for document 5627 of 5826
# Get embedding and write document for document 5628 of 5826
# Get embedding and write document for document 5629 of 5826
# Get embedding and write document for document 5630 of 5826
# Get embedding and write document for document 5631 of 5826
# Get embedding and write document for document 5632 of 5826
# Get embedding and write document for document 5633 of 5826
# Get embedding and write document for document 5634 of 5826
# Get embedding and write document for document 5635 of 5826
# Get embedding and write document for document 5636 of 5826
# Get embedding and write document for document 5637 of 5826
# Get embedding and write document for document 5638 of 5826
# Get embedding and write document for document 5639 of 5826
# Get embedding and write document for document 5640 of 5826
# Get embedding and write document for document 5641 of 5826
# Get embedding and write document for document 5642 of 5826
# Get embedding and write document for document 5643 of 5826
# Get embedding and write document for document 5644 of 5826
# Get embedding and write document for document 5645 of 5826
# Get embedding and write document for document 5646 of 5826
# Get embedding and write document for document 5647 of 5826
# Get embedding and write document for document 5648 of 5826
# Get embedding and write document for document 5649 of 5826
# Get embedding and write document for document 5650 of 5826
# Get embedding and write document for document 5651 of 5826
# Get embedding and write document for document 5652 of 5826
# Get embedding and write document for document 5653 of 5826
# Get embedding and write document for document 5654 of 5826
# Get embedding and write document for document 5655 of 5826
# Get embedding and write document for document 5656 of 5826
# Get embedding and write document for document 5657 of 5826
# Get embedding and write document for document 5658 of 5826
# Get embedding and write document for document 5659 of 5826
# Get embedding and write document for document 5660 of 5826
# Get embedding and write document for document 5661 of 5826
# Get embedding and write document for document 5662 of 5826
# Get embedding and write document for document 5663 of 5826
# Get embedding and write document for document 5664 of 5826
# Get embedding and write document for document 5665 of 5826
# Get embedding and write document for document 5666 of 5826
# Get embedding and write document for document 5667 of 5826
# Get embedding and write document for document 5668 of 5826
# Get embedding and write document for document 5669 of 5826
# Get embedding and write document for document 5670 of 5826
# Get embedding and write document for document 5671 of 5826
# Get embedding and write document for document 5672 of 5826
# Get embedding and write document for document 5673 of 5826
# Get embedding and write document for document 5674 of 5826
# Get embedding and write document for document 5675 of 5826
# Get embedding and write document for document 5676 of 5826
# Get embedding and write document for document 5677 of 5826
# Get embedding and write document for document 5678 of 5826
# Get embedding and write document for document 5679 of 5826
# Get embedding and write document for document 5680 of 5826
# Get embedding and write document for document 5681 of 5826
# Get embedding and write document for document 5682 of 5826
# Get embedding and write document for document 5683 of 5826
# Get embedding and write document for document 5684 of 5826
# Get embedding and write document for document 5685 of 5826
# Get embedding and write document for document 5686 of 5826
# Get embedding and write document for document 5687 of 5826
# Get embedding and write document for document 5688 of 5826
# Get embedding and write document for document 5689 of 5826
# Get embedding and write document for document 5690 of 5826
# Get embedding and write document for document 5691 of 5826
# Get embedding and write document for document 5692 of 5826
# Get embedding and write document for document 5693 of 5826
# Get embedding and write document for document 5694 of 5826
# Get embedding and write document for document 5695 of 5826
# Get embedding and write document for document 5696 of 5826
# Get embedding and write document for document 5697 of 5826
# Get embedding and write document for document 5698 of 5826
# Get embedding and write document for document 5699 of 5826
# Get embedding and write document for document 5700 of 5826
# Get embedding and write document for document 5701 of 5826
# Get embedding and write document for document 5702 of 5826
# Get embedding and write document for document 5703 of 5826
# Get embedding and write document for document 5704 of 5826
# Get embedding and write document for document 5705 of 5826
# Get embedding and write document for document 5706 of 5826
# Get embedding and write document for document 5707 of 5826
# Get embedding and write document for document 5708 of 5826
# Get embedding and write document for document 5709 of 5826
# Get embedding and write document for document 5710 of 5826
# Get embedding and write document for document 5711 of 5826
# Get embedding and write document for document 5712 of 5826
# Get embedding and write document for document 5713 of 5826
# Get embedding and write document for document 5714 of 5826
# Get embedding and write document for document 5715 of 5826
# Get embedding and write document for document 5716 of 5826
# Get embedding and write document for document 5717 of 5826
# Get embedding and write document for document 5718 of 5826
# Get embedding and write document for document 5719 of 5826
# Get embedding and write document for document 5720 of 5826
# Get embedding and write document for document 5721 of 5826
# Get embedding and write document for document 5722 of 5826
# Get embedding and write document for document 5723 of 5826
# Get embedding and write document for document 5724 of 5826
# Get embedding and write document for document 5725 of 5826
# Get embedding and write document for document 5726 of 5826
# Get embedding and write document for document 5727 of 5826
# Get embedding and write document for document 5728 of 5826
# Get embedding and write document for document 5729 of 5826
# Get embedding and write document for document 5730 of 5826
# Get embedding and write document for document 5731 of 5826
# Get embedding and write document for document 5732 of 5826
# Get embedding and write document for document 5733 of 5826
# Get embedding and write document for document 5734 of 5826
# Get embedding and write document for document 5735 of 5826
# Get embedding and write document for document 5736 of 5826
# Get embedding and write document for document 5737 of 5826
# Get embedding and write document for document 5738 of 5826
# Get embedding and write document for document 5739 of 5826
# Get embedding and write document for document 5740 of 5826
# Get embedding and write document for document 5741 of 5826
# Get embedding and write document for document 5742 of 5826
# Get embedding and write document for document 5743 of 5826
# Get embedding and write document for document 5744 of 5826
# Get embedding and write document for document 5745 of 5826
# Get embedding and write document for document 5746 of 5826
# Get embedding and write document for document 5747 of 5826
# Get embedding and write document for document 5748 of 5826
# Get embedding and write document for document 5749 of 5826
# Get embedding and write document for document 5750 of 5826
# Get embedding and write document for document 5751 of 5826
# Get embedding and write document for document 5752 of 5826
# Get embedding and write document for document 5753 of 5826
# Get embedding and write document for document 5754 of 5826
# Get embedding and write document for document 5755 of 5826
# Get embedding and write document for document 5756 of 5826
# Get embedding and write document for document 5757 of 5826
# Get embedding and write document for document 5758 of 5826
# Get embedding and write document for document 5759 of 5826
# Get embedding and write document for document 5760 of 5826
# Get embedding and write document for document 5761 of 5826
# Get embedding and write document for document 5762 of 5826
# Get embedding and write document for document 5763 of 5826
# Get embedding and write document for document 5764 of 5826
# Get embedding and write document for document 5765 of 5826
# Get embedding and write document for document 5766 of 5826
# Get embedding and write document for document 5767 of 5826
# Get embedding and write document for document 5768 of 5826
# Get embedding and write document for document 5769 of 5826
# Get embedding and write document for document 5770 of 5826
# Get embedding and write document for document 5771 of 5826
# Get embedding and write document for document 5772 of 5826
# Get embedding and write document for document 5773 of 5826
# Get embedding and write document for document 5774 of 5826
# Get embedding and write document for document 5775 of 5826
# Get embedding and write document for document 5776 of 5826
# Get embedding and write document for document 5777 of 5826
# Get embedding and write document for document 5778 of 5826
# Get embedding and write document for document 5779 of 5826
# Get embedding and write document for document 5780 of 5826
# Get embedding and write document for document 5781 of 5826
# Get embedding and write document for document 5782 of 5826
# Get embedding and write document for document 5783 of 5826
# Get embedding and write document for document 5784 of 5826
# Get embedding and write document for document 5785 of 5826
# Get embedding and write document for document 5786 of 5826
# Get embedding and write document for document 5787 of 5826
# Get embedding and write document for document 5788 of 5826
# Get embedding and write document for document 5789 of 5826
# Get embedding and write document for document 5790 of 5826
# Get embedding and write document for document 5791 of 5826
# Get embedding and write document for document 5792 of 5826
# Get embedding and write document for document 5793 of 5826
# Get embedding and write document for document 5794 of 5826
# Get embedding and write document for document 5795 of 5826
# Get embedding and write document for document 5796 of 5826
# Get embedding and write document for document 5797 of 5826
# Get embedding and write document for document 5798 of 5826
# Get embedding and write document for document 5799 of 5826
# Get embedding and write document for document 5800 of 5826
# Get embedding and write document for document 5801 of 5826
# Get embedding and write document for document 5802 of 5826
# Get embedding and write document for document 5803 of 5826
# Get embedding and write document for document 5804 of 5826
# Get embedding and write document for document 5805 of 5826
# Get embedding and write document for document 5806 of 5826
# Get embedding and write document for document 5807 of 5826
# Get embedding and write document for document 5808 of 5826
# Get embedding and write document for document 5809 of 5826
# Get embedding and write document for document 5810 of 5826
# Get embedding and write document for document 5811 of 5826
# Get embedding and write document for document 5812 of 5826
# Get embedding and write document for document 5813 of 5826
# Get embedding and write document for document 5814 of 5826
# Get embedding and write document for document 5815 of 5826
# Get embedding and write document for document 5816 of 5826
# Get embedding and write document for document 5817 of 5826
# Get embedding and write document for document 5818 of 5826
# Get embedding and write document for document 5819 of 5826
# Get embedding and write document for document 5820 of 5826
# Get embedding and write document for document 5821 of 5826
# Get embedding and write document for document 5822 of 5826
# Get embedding and write document for document 5823 of 5826
# Get embedding and write document for document 5824 of 5826
# Get embedding and write document for document 5825 of 5826
# Get embedding and write document for document 5826 of 5826

# %% [markdown]
# ## Copy document chunks and embeddings to Google Cloud Storage for later indexing and retreival steps

# %%
# !gsutil cp -r documents  gs://doit-llm/documents
# !gsutil cp embeddings.json gs://doit-llm/embeddings/embeddings.json

# %% [markdown]
# # Index

# %% [markdown]
# ## Option 1 - Create Streaming Index

# %%
# %%writefile index.json
# {
#     displayName: "palm-langchain-document-answering",
#     description: "palm-langchain-document-answering",
#     metadata: {
#        contentsDeltaUri: "gs://doit-llm/embeddings",
#        config: {
#           dimensions: "768",
#           approximateNeighborsCount: 150,
#           distanceMeasureType: "DOT_PRODUCT_DISTANCE",
#           algorithmConfig: {
#              bruteForceConfig: {}
#           }
#        },
#     },
#     indexUpdateMethod: "STREAM_UPDATE"
# }

# %%
# !curl -X POST -H "Content-Type: application/json" \
-H "Authorization: Bearer `gcloud auth print-access-token`" \
https://us-central1-aiplatform.googleapis.com/v1/projects/sascha-playground-doit/locations/us-central1/indexes \
-d @index.json

# %% [markdown]
# ## Option 2 - Create Batch Index

# %%
index = aiplatform.MatchingEngineIndex.create_tree_ah_index(
      display_name=DISPLAY_NAME,
      contents_delta_uri=BUCKET,
      dimensions=DIMENSIONS,
      approximate_neighbors_count=150,
      distance_measure_type="DOT_PRODUCT_DISTANCE")
# Out:
# Creating MatchingEngineIndex
# INFO:google.cloud.aiplatform.matching_engine.matching_engine_index:Creating MatchingEngineIndex
# Create MatchingEngineIndex backing LRO: projects/234439745674/locations/us-central1/indexes/1788448021554397184/operations/6668007164503654400
# INFO:google.cloud.aiplatform.matching_engine.matching_engine_index:Create MatchingEngineIndex backing LRO: projects/234439745674/locations/us-central1/indexes/1788448021554397184/operations/6668007164503654400
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-0a7ed686e729> in <cell line: 1>()
# ----> 1 index = aiplatform.MatchingEngineIndex.create_tree_ah_index(
#       2       display_name=DISPLAY_NAME,
#       3       contents_delta_uri=BUCKET,
#       4       dimensions=DIMENSIONS,
#       5       approximate_neighbors_count=150,
#
# /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform/matching_engine/matching_engine_index.py in create_tree_ah_index(cls, display_name, contents_delta_uri, dimensions, approximate_neighbors_count, leaf_node_embedding_count, leaf_nodes_to_search_percent, distance_measure_type, description, labels, project, location, credentials, request_metadata, sync)
#     484         )
#     485
# --> 486         return cls._create(
#     487             display_name=display_name,
#     488             contents_delta_uri=contents_delta_uri,
#
# /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform/base.py in wrapper(*args, **kwargs)
#     812                 if self:
#     813                     VertexAiResourceNounWithFutureManager.wait(self)
# --> 814                 return method(*args, **kwargs)
#     815
#     816             # callbacks to call within the Future (in same Thread)
#
# /usr/local/lib/python3.10/dist-packages/google/cloud/aiplatform/matching_engine/matching_engine_index.py in _create(cls, display_name, contents_delta_uri, config, description, labels, project, location, credentials, request_metadata, sync)
#     193         _LOGGER.log_create_with_lro(cls, create_lro)
#     194
# --> 195         created_index = create_lro.result(timeout=None)
#     196
#     197         _LOGGER.log_create_complete(cls, created_index, "index")
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/future/polling.py in result(self, timeout, retry, polling)
#     254         """
#     255
# --> 256         self._blocking_poll(timeout=timeout, retry=retry, polling=polling)
#     257
#     258         if self._exception is not None:
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/future/polling.py in _blocking_poll(self, timeout, retry, polling)
#     135
#     136         try:
# --> 137             polling(self._done_or_raise)(retry=retry)
#     138         except exceptions.RetryError:
#     139             raise concurrent.futures.TimeoutError(
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/retry.py in retry_wrapped_func(*args, **kwargs)
#     347                 self._initial, self._maximum, multiplier=self._multiplier
#     348             )
# --> 349             return retry_target(
#     350                 target,
#     351                 self._predicate,
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/retry.py in retry_target(target, predicate, sleep_generator, timeout, on_error, **kwargs)
#     215             "Retrying due to {}, sleeping {:.1f}s ...".format(last_exc, sleep)
#     216         )
# --> 217         time.sleep(sleep)
#     218
#     219     raise ValueError("Sleep generator stopped yielding sleep values.")
#
# KeyboardInterrupt:

# %% [markdown]
# ## Create Endpoint

# %%
REGION = "us-central1"
ENDPOINT = "{}-aiplatform.googleapis.com".format(REGION)

PROJECT_ID = "sascha-playground-doit"
PARENT = "projects/{}/locations/{}".format(PROJECT_ID, REGION)

PROJECT_NUMBER = !gcloud projects list --filter="PROJECT_ID:'{PROJECT_ID}'" --format='value(PROJECT_NUMBER)'
PROJECT_NUMBER = PROJECT_NUMBER[0]

NETWORK_NAME = "matching-engine-vpc-network"

VPC_NETWORK_NAME = "projects/{}/global/networks/{}".format(PROJECT_NUMBER, NETWORK_NAME)
VPC_NETWORK_NAME
# Out:
# 'projects/234439745674/global/networks/matching-engine-vpc-network'

# %%
index_endpoint = aiplatform.MatchingEngineIndexEndpoint.create(
    display_name=DISPLAY_NAME,
    description=DISPLAY_NAME,
    network=VPC_NETWORK_NAME,
    #IMPORTANT if you want to use a public endpoint you need to use aiplatform_v1beta1 when query or inserting vectors
    # https://cloud.google.com/vertex-ai/docs/matching-engine/deploy-index-public
    # public_endpoint_enabled=True
)
# Out:
# Creating MatchingEngineIndexEndpoint
# INFO:google.cloud.aiplatform.matching_engine.matching_engine_index_endpoint:Creating MatchingEngineIndexEndpoint
# Create MatchingEngineIndexEndpoint backing LRO: projects/234439745674/locations/us-central1/indexEndpoints/4797978472544731136/operations/8752047892069351424
# INFO:google.cloud.aiplatform.matching_engine.matching_engine_index_endpoint:Create MatchingEngineIndexEndpoint backing LRO: projects/234439745674/locations/us-central1/indexEndpoints/4797978472544731136/operations/8752047892069351424
# MatchingEngineIndexEndpoint created. Resource name: projects/234439745674/locations/us-central1/indexEndpoints/4797978472544731136
# INFO:google.cloud.aiplatform.matching_engine.matching_engine_index_endpoint:MatchingEngineIndexEndpoint created. Resource name: projects/234439745674/locations/us-central1/indexEndpoints/4797978472544731136
# To use this MatchingEngineIndexEndpoint in another session:
# INFO:google.cloud.aiplatform.matching_engine.matching_engine_index_endpoint:To use this MatchingEngineIndexEndpoint in another session:
# index_endpoint = aiplatform.MatchingEngineIndexEndpoint('projects/234439745674/locations/us-central1/indexEndpoints/4797978472544731136')
# INFO:google.cloud.aiplatform.matching_engine.matching_engine_index_endpoint:index_endpoint = aiplatform.MatchingEngineIndexEndpoint('projects/234439745674/locations/us-central1/indexEndpoints/4797978472544731136')

# %% [markdown]
# ## Deploy Index

# %%
# uncomment if you want to use existing index or endpoint

INDEX_RESOURCE_NAME = "projects/234439745674/locations/us-central1/indexes/1788448021554397184"
index = aiplatform.MatchingEngineIndex(index_name=INDEX_RESOURCE_NAME)

ENDPOINT_RESOURCE_NAME = "projects/234439745674/locations/us-central1/indexEndpoints/4797978472544731136"
index_endpoint = aiplatform.MatchingEngineIndexEndpoint(index_endpoint_name=ENDPOINT_RESOURCE_NAME)

# %%
deployed_index = index_endpoint.deploy_index(
    index=index, deployed_index_id=DISPLAY_NAME.replace('-','_')
)
# Out:
# Deploying index MatchingEngineIndexEndpoint index_endpoint: projects/234439745674/locations/us-central1/indexEndpoints/4797978472544731136
# INFO:google.cloud.aiplatform.matching_engine.matching_engine_index_endpoint:Deploying index MatchingEngineIndexEndpoint index_endpoint: projects/234439745674/locations/us-central1/indexEndpoints/4797978472544731136
# Deploy index MatchingEngineIndexEndpoint index_endpoint backing LRO: projects/234439745674/locations/us-central1/indexEndpoints/4797978472544731136/operations/4082378028439568384
# INFO:google.cloud.aiplatform.matching_engine.matching_engine_index_endpoint:Deploy index MatchingEngineIndexEndpoint index_endpoint backing LRO: projects/234439745674/locations/us-central1/indexEndpoints/4797978472544731136/operations/4082378028439568384
# MatchingEngineIndexEndpoint index_endpoint Deployed index. Resource name: projects/234439745674/locations/us-central1/indexEndpoints/4797978472544731136
# INFO:google.cloud.aiplatform.matching_engine.matching_engine_index_endpoint:MatchingEngineIndexEndpoint index_endpoint Deployed index. Resource name: projects/234439745674/locations/us-central1/indexEndpoints/4797978472544731136

# %% [markdown]
# # The fun part (needs to be inside the same VPC)
# Matching Engine now supports in beta public endpoints. Stayed tuned for a dedicated article on that.

# %%
INDEX='8624771518414454784'
ENDPOINT='1017628797832265728'
DOCS_BUCKET='doit-llm'

from langchain.embeddings import VertexAIEmbeddings
embeddings = VertexAIEmbeddings()

# %%
from langchain.vectorstores.matching_engine import MatchingEngine
from langchain.agents import Tool

def matching_engine_search(question):

    vector_store = MatchingEngine.from_components(
                        index_id=INDEX,
                        region=REGION,
                        embedding=embeddings,
                        project_id=PROJECT_ID,
                        endpoint_id=ENDPOINT,
                        gcs_bucket_name=DOCS_BUCKET)

    relevant_documentation=vector_store.similarity_search(question, k=8)
    context = "\n".join([doc.page_content for doc in relevant_documentation])[:10000]
    return str(context)

# %%
question = "what is the latency for Vertex AI Matching Engine?"

# %%
from vertexai.preview.language_models import TextGenerationModel

matching_engine_response=matching_engine_search(question)

prompt=f"""
Follow exactly those 3 steps:
1. Read the context below and aggregrate this data
Context : {matching_engine_response}
2. Answer the question using only this context
3. Show the source for your answers
User Question: {question}


If you don't have any context and are unsure of the answer, reply that you don't know about this topic.
"""

model = TextGenerationModel.from_pretrained(TEXT_GENERATION_MODEL)
response = model.predict(
        prompt,
        temperature=0.2,
        top_k=40,
        top_p=.8,
        max_output_tokens=1024,
)

print(f"Question: \n{question}")
print(f"Response: \n{response.text}")

# %% [markdown]
# ## Direct usage of Vertex AI Matching Engine (only to showase the direct usage for document retrieval)

# %%
embedding = embeddings.embed_query("what is the latency for Vertex AI Matching Engine?")
print(embedding)
response = index_endpoint.match(
    deployed_index_id="palm-langchain-document-answering",
    queries=[embedding]
)

response

# %% [markdown]
# # Little Index Helper

# %%
# !gcloud ai index-endpoints list --project="sascha-playground-doit" --region="us-central1"

# %%
# !gcloud ai index-endpoints undeploy-index "2199120012575244288" \
  --deployed-index-id="image_similarity_vpc" \
  --project="sascha-playground-doit" \
  --region="us-central1"

# %%
# !gcloud ai indexes list \
  --project="sascha-playground-doit" \
  --region="us-central1"

# %%
# !gcloud -q ai indexes delete "projects/234439745674/locations/us-central1/indexes/1910889636423532544" \
  --project="sascha-playground-doit" \
  --region="us-central1"

# %%
# !gcloud ai index-endpoints delete 5731859668712554496 \
  --project="sascha-playground-doit" \
  --region="us-central1" \
  --quiet
